# %%
# %load_ext autoreload
# %autoreload 2
# %autosave 5

import torch
import collections
from copy import deepcopy

from sharedvariables import get_video_sessions
from train_model import train_model_demo

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()


video_sessions_registered = get_video_sessions(should_be_registered=True, should_have_marked_cells=True)
train_params = collections.OrderedDict(
    epochs=250,
    lr = .001,
    
    weight_decay=0.01,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)
# Out:
# Autosaving every 5 seconds
# Using device: cuda

# %% [markdown]
# # standardise vs no standardise

# %%
train_params = collections.OrderedDict(
    epochs=250,
    lr = .001,
    
    weight_decay=0.01,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (55733, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best train acc  train loss  Best train epoch  Best valid acc  valid loss  Best valid epoch
# 0        0.907247    0.000004               240        0.893368     0.00002               249
#       lr    wd  epochs batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  0.001  0.01     250        all             60           20     True          53680           13420
#       e  train loss  valid loss  train acc  valid acc  Best loss?  Best Acc?  last loss  last acc     lr
# 0     0    0.000011    0.000046   0.831148   0.828390        True       True          0         0  0.001
# 1    20    0.000010    0.000042   0.831148   0.828390        True      False          0         1  0.001
# 2    40    0.000008    0.000034   0.847243   0.842772        True       True          0         0  0.001
# ..  ...         ...         ...        ...        ...         ...        ...        ...       ...    ...
# 11  220    0.000005    0.000021   0.895343   0.887183       False      False          1         5  0.001
# 12  240    0.000004    0.000020   0.907247   0.893145        True       True          0         0  0.001
# 13  249    0.000005    0.000020   0.905402   0.893368       False       True          1         0  0.001
#
# [14 rows x 10 columns]
# 100%|██████████| 250/250 [23:08<00:00,  5.56s/it]
# Run duration  1388.767019033432
# Saving results to directory: ./cache/models/model_va_0.893_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11367 cell patches and 55733 non cell patches.
#
# Brief evaluation - best validation accuracy model
# ----------------
# Epoch:	 249
# Training accuracy:	 0.905
# Validation accuracy:	 0.893
#
# Positive accuracy:	 0.605
# Negative accuracy:	 0.964
#
# 0.905 0.893 0.605 0.964
#
#
# Brief evaluation - best training accuracy model
# ----------------
# Epoch:	 240
# Training accuracy:	 0.907
# Validation accuracy:	 0.893
#
# Positive accuracy:	 0.547
# Negative accuracy:	 0.977
# 0.8933681073025336

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (55740, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best train acc  train loss  Best train epoch  Best valid acc  valid loss  Best valid epoch
# 0        0.899041    0.000005               240        0.891819    0.000021               140
#       lr    wd  epochs batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  0.001  0.01     250        all             60           20     True          53685           13422
#       e  train loss  valid loss  train acc  valid acc  Best loss?  Best Acc?  last loss  last acc     lr
# 0     0    0.000016    0.000063   0.170159   0.166294        True       True          0         0  0.001
# 1    20    0.000012    0.000048   0.831573   0.835121        True       True          0         0  0.001
# 2    40    0.000010    0.000038   0.864022   0.863657        True       True          0         0  0.001
# ..  ...         ...         ...        ...        ...         ...        ...        ...       ...    ...
# 11  220    0.000006    0.000027   0.864767   0.853375       False      False          1         4  0.001
# 12  240    0.000005    0.000021   0.899041   0.888094       False      False          2         5  0.001
# 13  249    0.000006    0.000028   0.874341   0.855983       False      False          3         6  0.001
#
# [14 rows x 10 columns]
# 100%|██████████| 250/250 [23:13<00:00,  5.57s/it]
# Run duration  1393.167158126831
# Saving results to directory: ./cache/models/model_va_0.892_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11367 cell patches and 55740 non cell patches.
#
# Brief evaluation - best validation accuracy model
# ----------------
# Epoch:	 140
# Training accuracy:	 0.896
# Validation accuracy:	 0.892
#
# Positive accuracy:	 0.590
# Negative accuracy:	 0.957
#
# 0.896 0.892 0.590 0.957
#
#
# Brief evaluation - best training accuracy model
# ----------------
# Epoch:	 240
# Training accuracy:	 0.899
# Validation accuracy:	 0.888
#
# Positive accuracy:	 0.504
# Negative accuracy:	 0.977
# 0.89181940098346

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (55728, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best train acc  train loss  Best train epoch  Best valid acc  valid loss  Best valid epoch
# 0        0.904669    0.000005               249        0.890454    0.000021               160
#       lr    wd  epochs batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  0.001  0.01     250        all             60           20     True          53676           13419
#       e  train loss  valid loss  train acc  valid acc  Best loss?  Best Acc?  last loss  last acc     lr
# 0     0    0.000015    0.000059   0.169014   0.171026        True       True          0         0  0.001
# 1    20    0.000013    0.000052   0.485245   0.495566        True       True          0         0  0.001
# 2    40    0.000010    0.000040   0.842816   0.843058        True       True          0         0  0.001
# ..  ...         ...         ...        ...        ...         ...        ...        ...       ...    ...
# 11  220    0.000005    0.000021   0.896136   0.887995        True      False          0         3  0.001
# 12  240    0.000007    0.000031   0.843748   0.834414       False      False          1         4  0.001
# 13  249    0.000005    0.000021   0.904669   0.889783        True      False          0         5  0.001
#
# [14 rows x 10 columns]
# 100%|██████████| 250/250 [23:19<00:00,  5.60s/it]
# Run duration  1399.7118508815765
# Saving results to directory: ./cache/models/model_va_0.890_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11367 cell patches and 55728 non cell patches.
#
# Brief evaluation - best validation accuracy model
# ----------------
# Epoch:	 160
# Training accuracy:	 0.897
# Validation accuracy:	 0.890
#
# Positive accuracy:	 0.524
# Negative accuracy:	 0.971
#
# 0.897 0.890 0.524 0.971
#
#
# Brief evaluation - best training accuracy model
# ----------------
# Epoch:	 249
# Training accuracy:	 0.905
# Validation accuracy:	 0.890
#
# Positive accuracy:	 0.550
# Negative accuracy:	 0.973
# 0.8904538341158059

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=False,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (55705, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False             False    5
#    Best train acc  train loss  Best train epoch  Best valid acc  valid loss  Best valid epoch
# 0        0.892335    0.000005               240        0.888483    0.000022               240
#       lr    wd  epochs batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  0.001  0.01     250        all             60           20     True          53657           13415
#       e  train loss  valid loss  train acc  valid acc  Best loss?  Best Acc?  last loss  last acc     lr
# 0     0    0.000013    0.000052   0.657659   0.653373        True       True          0         0  0.001
# 1    20    0.000010    0.000039   0.830628   0.830116        True       True          0         0  0.001
# 2    40    0.000009    0.000036   0.847271   0.844801        True       True          0         0  0.001
# ..  ...         ...         ...        ...        ...         ...        ...        ...       ...    ...
# 11  220    0.000007    0.000030   0.850979   0.848975       False      False          2         2  0.001
# 12  240    0.000005    0.000022   0.892335   0.888483        True       True          0         0  0.001
# 13  249    0.000005    0.000022   0.886296   0.880134       False      False          1         1  0.001
#
# [14 rows x 10 columns]
# 100%|██████████| 250/250 [13:16<00:00,  3.19s/it]
# Run duration  796.2597985267639
# Saving results to directory: ./cache/models/model_va_0.888_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_false_da_false
# Done
#
# Model trained on 11367 cell patches and 55705 non cell patches.
#
# Brief evaluation - best validation accuracy model
# ----------------
# Epoch:	 240
# Training accuracy:	 0.892
# Validation accuracy:	 0.888
#
# Positive accuracy:	 0.484
# Negative accuracy:	 0.975
#
# 0.892 0.888 0.484 0.975
#
#
# Brief evaluation - best training accuracy model
# ----------------
# Epoch:	 240
# Training accuracy:	 0.892
# Validation accuracy:	 0.888
#
# Positive accuracy:	 0.484
# Negative accuracy:	 0.975
# 0.888483041371599

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=False,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (55727, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False             False    5
#    Best train acc  train loss  Best train epoch  Best valid acc  valid loss  Best valid epoch
# 0        0.890489    0.000005               180          0.8871    0.000022               180
#       lr    wd  epochs batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  0.001  0.01     250        all             60           20     True          53675           13419
#       e  train loss  valid loss  train acc  valid acc  Best loss?  Best Acc?  last loss  last acc     lr
# 0     0    0.000013    0.000052   0.169334   0.169759        True       True          0         0  0.001
# 1    20    0.000012    0.000049   0.834616   0.833147        True       True          0         0  0.001
# 2    40    0.000010    0.000041   0.847005   0.843804        True       True          0         0  0.001
# ..  ...         ...         ...        ...        ...         ...        ...        ...       ...    ...
# 11  220    0.000005    0.000022   0.884788   0.881362        True      False          0         2  0.001
# 12  240    0.000005    0.000023   0.876237   0.872941       False      False          1         3  0.001
# 13  249    0.000005    0.000022   0.889073   0.884641        True      False          0         4  0.001
#
# [14 rows x 10 columns]
# 100%|██████████| 250/250 [13:15<00:00,  3.18s/it]
# Run duration  795.0755887031555
# Saving results to directory: ./cache/models/model_va_0.887_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_false_da_false
# Done
#
# Model trained on 11367 cell patches and 55727 non cell patches.
#
# Brief evaluation - best validation accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.890
# Validation accuracy:	 0.887
#
# Positive accuracy:	 0.487
# Negative accuracy:	 0.972
#
# 0.890 0.887 0.487 0.972
#
#
# Brief evaluation - best training accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.890
# Validation accuracy:	 0.887
#
# Positive accuracy:	 0.487
# Negative accuracy:	 0.972
# 0.8871003800581265

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=False,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (55714, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False             False    5
#    Best train acc  train loss  Best train epoch  Best valid acc  valid loss  Best valid epoch
# 0        0.891454    0.000005               220        0.884475    0.000021               220
#       lr    wd  epochs batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  0.001  0.01     250        all             60           20     True          53664           13417
#       e  train loss  valid loss  train acc  valid acc  Best loss?  Best Acc?  last loss  last acc     lr
# 0     0    0.000011    0.000046   0.830687   0.829992        True       True          0         0  0.001
# 1    20    0.000010    0.000041   0.830687   0.829992        True      False          0         1  0.001
# 2    40    0.000009    0.000035   0.836855   0.834166        True       True          0         0  0.001
# ..  ...         ...         ...        ...        ...         ...        ...        ...       ...    ...
# 11  220    0.000005    0.000021   0.891454   0.884475        True       True          0         0  0.001
# 12  240    0.000014    0.000057   0.832122   0.831557       False      False          1         1  0.001
# 13  249    0.000007    0.000030   0.848651   0.848625       False      False          2         2  0.001
#
# [14 rows x 10 columns]
# 100%|██████████| 250/250 [13:15<00:00,  3.18s/it]
# Run duration  795.8655383586884
# Saving results to directory: ./cache/models/model_va_0.884_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_false_da_false
# Done
#
# Model trained on 11367 cell patches and 55714 non cell patches.
#
# Brief evaluation - best validation accuracy model
# ----------------
# Epoch:	 220
# Training accuracy:	 0.891
# Validation accuracy:	 0.884
#
# Positive accuracy:	 0.470
# Negative accuracy:	 0.976
#
# 0.891 0.884 0.470 0.976
#
#
# Brief evaluation - best training accuracy model
# ----------------
# Epoch:	 220
# Training accuracy:	 0.891
# Validation accuracy:	 0.884
#
# Positive accuracy:	 0.470
# Negative accuracy:	 0.976
# 0.884474919877767

# %% [markdown]
# # Temporality - temporal patches - temporal vs no temporal

# %%
video_sessions_registered = get_video_sessions(should_be_registered=True, should_have_marked_cells=True)
train_params = collections.OrderedDict(
    epochs=200,
    lr = .001,
    
    weight_decay=0.01,
    batch_size=1024 * 5, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

# %% [markdown]
# ## Temporal width  1 - ps 31

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10444, 31, 31, 3). Non cell patches: (51095, 31, 31, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          31               1       False              True    5
#    Best train acc  train loss  Best train epoch  Best valid acc  valid loss  Best valid epoch
# 0        0.993317    0.000006               180        0.901771     0.00006                60
#       lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  0.001  0.01     200        5120             60           20     True          49231           12308
#       e  train loss  valid loss  train acc  valid acc  Best loss?  Best Acc?  last loss  last acc     lr
# 0     0    0.000134    0.000161   0.829335   0.834092        True       True          0         0  0.001
# 1    20    0.000055    0.000069   0.892040   0.887309        True       True          0         0  0.001
# 2    40    0.000051    0.000073   0.899047   0.880728       False      False          1         1  0.001
# ..  ...         ...         ...        ...        ...         ...        ...        ...       ...    ...
# 8   160    0.000013    0.000107   0.978306   0.881947       False      False          5         5  0.001
# 9   180    0.000006    0.000108   0.993317   0.879672       False      False          6         6  0.001
# 10  199    0.000059    0.000070   0.882757   0.885115       False      False          7         7  0.001
#
# [11 rows x 10 columns]
# 100%|██████████| 200/200 [19:38<00:00,  5.89s/it]
# Run duration  1178.8501257896423
# Saving results to directory: ./cache/models/model_va_0.902_ps_31_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10444 cell patches and 51095 non cell patches.
#
# Brief evaluation - best validation accuracy model
# ----------------
# Epoch:	 60
# Training accuracy:	 0.915
# Validation accuracy:	 0.902
#
# Positive accuracy:	 0.597
# Negative accuracy:	 0.977
#
# 0.915 0.902 0.597 0.977
#
#
# Brief evaluation - best training accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.993
# Validation accuracy:	 0.880
#
# Positive accuracy:	 0.928
# Negative accuracy:	 0.979
# 0.901771205719857

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10444, 31, 31, 3). Non cell patches: (51079, 31, 31, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          31               1       False              True    5
#    Best train acc  train loss  Best train epoch  Best valid acc  valid loss  Best valid epoch
# 0        0.977264    0.000012               100        0.894027    0.000062               140
#       lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  0.001  0.01     200        5120             60           20     True          49218           12305
#       e  train loss  valid loss  train acc  valid acc  Best loss?  Best Acc?  last loss  last acc     lr
# 0     0    0.000135    0.000162   0.830347   0.829825        True       True          0         0  0.001
# 1    20    0.000056    0.000070   0.884778   0.879074        True       True          0         0  0.001
# 2    40    0.000043    0.000065   0.917815   0.892889        True       True          0         0  0.001
# ..  ...         ...         ...        ...        ...         ...        ...        ...       ...    ...
# 8   160    0.000042    0.000067   0.922163   0.886875       False      False          1         1  0.001
# 9   180    0.000038    0.000080   0.923788   0.881349       False      False          2         2  0.001
# 10  199    0.000030    0.000097   0.942562   0.868915       False      False          3         3  0.001
#
# [11 rows x 10 columns]
# 100%|██████████| 200/200 [19:21<00:00,  5.81s/it]
# Run duration  1161.3096849918365
# Saving results to directory: ./cache/models/model_va_0.894_ps_31_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10444 cell patches and 51079 non cell patches.
#
# Brief evaluation - best validation accuracy model
# ----------------
# Epoch:	 140
# Training accuracy:	 0.909
# Validation accuracy:	 0.894
#
# Positive accuracy:	 0.577
# Negative accuracy:	 0.973
#
# 0.909 0.894 0.577 0.973
#
#
# Brief evaluation - best training accuracy model
# ----------------
# Epoch:	 100
# Training accuracy:	 0.977
# Validation accuracy:	 0.884
#
# Positive accuracy:	 0.815
# Negative accuracy:	 0.988
# 0.8940268183665177

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10444, 31, 31, 3). Non cell patches: (51068, 31, 31, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          31               1       False              True    5
#    Best train acc  train loss  Best train epoch  Best valid acc  valid loss  Best valid epoch
# 0        0.993294    0.000006               180         0.89913    0.000061               140
#       lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  0.001  0.01     200        5120             60           20     True          49209           12303
#       e  train loss  valid loss  train acc  valid acc  Best loss?  Best Acc?  last loss  last acc     lr
# 0     0    0.000131    0.000157   0.829137   0.834512        True       True          0         0  0.001
# 1    20    0.000053    0.000066   0.895019   0.892872        True       True          0         0  0.001
# 2    40    0.000046    0.000068   0.910585   0.888564       False      False          1         1  0.001
# ..  ...         ...         ...        ...        ...         ...        ...        ...       ...    ...
# 8   160    0.000022    0.000085   0.957691   0.887263       False      False          1         1  0.001
# 9   180    0.000006    0.000102   0.993294   0.884662       False      False          2         2  0.001
# 10  199    0.000044    0.000062   0.914731   0.898886       False      False          3         3  0.001
#
# [11 rows x 10 columns]
# 100%|██████████| 200/200 [19:23<00:00,  5.82s/it]
# Run duration  1163.4153220653534
# Saving results to directory: ./cache/models/model_va_0.899_ps_31_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10444 cell patches and 51068 non cell patches.
#
# Brief evaluation - best validation accuracy model
# ----------------
# Epoch:	 140
# Training accuracy:	 0.920
# Validation accuracy:	 0.899
#
# Positive accuracy:	 0.600
# Negative accuracy:	 0.981
#
# 0.920 0.899 0.600 0.981
#
#
# Brief evaluation - best training accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.993
# Validation accuracy:	 0.885
#
# Positive accuracy:	 0.907
# Negative accuracy:	 0.985
# 0.899130293424368

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10444, 31, 31, 3). Non cell patches: (51107, 31, 31, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          31               1       False              True    5
#    Best train acc  train loss  Best train epoch  Best valid acc  valid loss  Best valid epoch
# 0        0.964846     0.00002               199        0.895622    0.000062               160
#       lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  0.001  0.01     200        5120             60           20     True          49240           12311
#       e  train loss  valid loss  train acc  valid acc  Best loss?  Best Acc?  last loss  last acc     lr
# 0     0    0.000128    0.000153   0.830037   0.831452        True       True          0         0  0.001
# 1    20    0.000052    0.000067   0.900305   0.893429        True       True          0         0  0.001
# 2    40    0.000053    0.000079   0.892486   0.875558       False      False          1         1  0.001
# ..  ...         ...         ...        ...        ...         ...        ...        ...       ...    ...
# 8   160    0.000043    0.000062   0.920654   0.895622        True       True          0         0  0.001
# 9   180    0.000033    0.000075   0.934444   0.887743       False      False          1         1  0.001
# 10  199    0.000020    0.000090   0.964846   0.875802       False      False          2         2  0.001
#
# [11 rows x 10 columns]
# 100%|██████████| 200/200 [19:40<00:00,  5.90s/it]
# Run duration  1180.7739765644073
# Saving results to directory: ./cache/models/model_va_0.896_ps_31_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10444 cell patches and 51107 non cell patches.
#
# Brief evaluation - best validation accuracy model
# ----------------
# Epoch:	 160
# Training accuracy:	 0.921
# Validation accuracy:	 0.896
#
# Positive accuracy:	 0.716
# Negative accuracy:	 0.956
#
# 0.921 0.896 0.716 0.956
#
#
# Brief evaluation - best training accuracy model
# ----------------
# Epoch:	 199
# Training accuracy:	 0.965
# Validation accuracy:	 0.876
#
# Positive accuracy:	 0.842
# Negative accuracy:	 0.968
# 0.8956218016408091

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10444, 31, 31, 3). Non cell patches: (51089, 31, 31, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          31               1       False              True    5
#    Best train acc  train loss  Best train epoch  Best valid acc  valid loss  Best valid epoch
# 0        0.983687     0.00001               160        0.899244    0.000062               180
#       lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  0.001  0.01     200        5120             60           20     True          49226           12307
#       e  train loss  valid loss  train acc  valid acc  Best loss?  Best Acc?  last loss  last acc     lr
# 0     0    0.000121    0.000145   0.830455   0.829528        True       True          0         0  0.001
# 1    20    0.000054    0.000068   0.891805   0.886894        True       True          0         0  0.001
# 2    40    0.000057    0.000080   0.888047   0.866499       False      False          1         1  0.001
# ..  ...         ...         ...        ...        ...         ...        ...        ...       ...    ...
# 8   160    0.000010    0.000100   0.983687   0.885106       False      False          7         2  0.001
# 9   180    0.000045    0.000062   0.913217   0.899244        True       True          0         0  0.001
# 10  199    0.000031    0.000093   0.940499   0.882831       False      False          1         1  0.001
#
# [11 rows x 10 columns]
# 100%|██████████| 200/200 [19:41<00:00,  5.91s/it]
# Run duration  1181.7507584095001
# Saving results to directory: ./cache/models/model_va_0.899_ps_31_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10444 cell patches and 51089 non cell patches.
#
# Brief evaluation - best validation accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.913
# Validation accuracy:	 0.899
#
# Positive accuracy:	 0.628
# Negative accuracy:	 0.968
#
# 0.913 0.899 0.628 0.968
#
#
# Brief evaluation - best training accuracy model
# ----------------
# Epoch:	 160
# Training accuracy:	 0.984
# Validation accuracy:	 0.885
#
# Positive accuracy:	 0.824
# Negative accuracy:	 0.993
# 0.8992443324937027

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10444, 31, 31, 3). Non cell patches: (51094, 31, 31, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          31               1       False              True    5
#    Best train acc  train loss  Best train epoch  Best valid acc  valid loss  Best valid epoch
# 0        0.982815     0.00001               140        0.896246    0.000064                20
#       lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  0.001  0.01     200        5120             60           20     True          49230           12308
#       e  train loss  valid loss  train acc  valid acc  Best loss?  Best Acc?  last loss  last acc     lr
# 0     0    0.000142    0.000171   0.320963   0.320523        True       True          0         0  0.001
# 1    20    0.000055    0.000067   0.899939   0.896246        True       True          0         0  0.001
# 2    40    0.000043    0.000065   0.915052   0.896246        True      False          0         1  0.001
# ..  ...         ...         ...        ...        ...         ...        ...        ...       ...    ...
# 8   160    0.015765    0.019248   0.170892   0.165015       False      False          6         7  0.001
# 9   180    0.000056    0.000067   0.889986   0.890803       False      False          7         8  0.001
# 10  199    0.000050    0.000064   0.901625   0.895190        True      False          0         9  0.001
#
# [11 rows x 10 columns]
# 100%|██████████| 200/200 [19:22<00:00,  5.81s/it]
# Run duration  1162.751751422882
# Saving results to directory: ./cache/models/model_va_0.896_ps_31_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10444 cell patches and 51094 non cell patches.
#
# Brief evaluation - best validation accuracy model
# ----------------
# Epoch:	 20
# Training accuracy:	 0.900
# Validation accuracy:	 0.896
#
# Positive accuracy:	 0.622
# Negative accuracy:	 0.956
#
# 0.900 0.896 0.622 0.956
#
#
# Brief evaluation - best training accuracy model
# ----------------
# Epoch:	 140
# Training accuracy:	 0.983
# Validation accuracy:	 0.892
#
# Positive accuracy:	 0.827
# Negative accuracy:	 0.993
# 0.896246343841404

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10444, 31, 31, 3). Non cell patches: (51077, 31, 31, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          31               1       False              True    5
#    Best train acc  train loss  Best train epoch  Best valid acc  valid loss  Best valid epoch
# 0        0.981713     0.00001               199        0.895327    0.000063               100
#       lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  0.001  0.01     200        5120             60           20     True          49216           12305
#       e  train loss  valid loss  train acc  valid acc  Best loss?  Best Acc?  last loss  last acc     lr
# 0     0    0.000148    0.000178   0.179901   0.178952        True       True          0         0  0.001
# 1    20    0.000055    0.000072   0.896111   0.886388        True       True          0         0  0.001
# 2    40    0.000047    0.000069   0.908688   0.884356        True      False          0         1  0.001
# ..  ...         ...         ...        ...        ...         ...        ...        ...       ...    ...
# 8   160    0.000014    0.000113   0.976532   0.866558       False      False          3         3  0.001
# 9   180    0.000015    0.000084   0.978097   0.881105       False      False          4         4  0.001
# 10  199    0.000010    0.000105   0.981713   0.881512       False      False          5         5  0.001
#
# [11 rows x 10 columns]
# 100%|██████████| 200/200 [19:38<00:00,  5.89s/it]
# Run duration  1178.1376099586487
# Saving results to directory: ./cache/models/model_va_0.895_ps_31_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10444 cell patches and 51077 non cell patches.
#
# Brief evaluation - best validation accuracy model
# ----------------
# Epoch:	 100
# Training accuracy:	 0.917
# Validation accuracy:	 0.895
#
# Positive accuracy:	 0.603
# Negative accuracy:	 0.976
#
# 0.917 0.895 0.603 0.976
#
#
# Brief evaluation - best training accuracy model
# ----------------
# Epoch:	 199
# Training accuracy:	 0.982
# Validation accuracy:	 0.882
#
# Positive accuracy:	 0.820
# Negative accuracy:	 0.991
# 0.8953271028037383

# %% [markdown]
# ## Temporal width 1 - patch size 25

# %%
model, results = train_model_demo(
                 patch_size=25,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=25,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=25,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=25,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=25,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=25,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=25,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ## Temporal width 2

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=2,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=2,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=2,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=2,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# # Patchsizes comparison 17 vs 19 vs 21 vs 23 - patch size comparison

# %%
video_sessions_registered = get_video_sessions(should_be_registered=True, should_have_marked_cells=True)
train_params = collections.OrderedDict(
    epochs=200,
    lr = .001,
    
    weight_decay=0.01,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

# %% [markdown]
# ## Patch size 15

# %%
model, results = train_model_demo(                
                 patch_size=15,
                 
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=15,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=15,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ## Patch size 17

# %%
model, results = train_model_demo(                
                 patch_size=17,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=17,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=17,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=17,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=17,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ## Patch size 19

# %%
model, results = train_model_demo(                
                 patch_size=19,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=19,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=19,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=19,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ## Patch size 21

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ## Patch size 23

# %%
model, results = train_model_demo(                
                 patch_size=23,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=23,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=23,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=23,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=23,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ## Patch Size 25

# %%
model, results = train_model_demo(                
                 patch_size=25,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=25,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=25,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=25,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=25,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ## Patch Size 31

# %%
model, results = train_model_demo(                
                 patch_size=31,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=31,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=31,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ## Patch Size 35

# %%
model, results = train_model_demo(                
                 patch_size=35,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=35,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ## Patch Size 37

# %%
model, results = train_model_demo(                
                 patch_size=37,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=37,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ### Mixed Channel Patches

# %%
train_params = collections.OrderedDict(
    epochs=250,
    lr = .001,
    
    weight_decay=0.01,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

# %% [markdown]
# ## mc - ps 19 - dc - 21 Aug

# %%
model, results = train_model_demo(
                 patch_size=19,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=19,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=19,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=19,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %% [markdown]
# ## mc - ps 21 - dc - 21 Aug

# %%
model, results = train_model_demo(
                 patch_size=21,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=21,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=21,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %% [markdown]
# ## mc - ps 25 - dc - 21 Aug

# %%
model, results = train_model_demo(
                 patch_size=25,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=25,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=25,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %% [markdown]
# ## mc - ps 27 - dc - 21 Aug

# %%
model, results = train_model_demo(
                 patch_size=27,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=27,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=27,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %% [markdown]
# ## mc - ps 31 - dc - 21 Aug

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %% [markdown]
# ## mc - ps 35 - dc - 21 Aug

# %%
model, results = train_model_demo(
                 patch_size=35,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=35,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=35,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=35,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=35,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %% [markdown]
# ### Number of negative per positive

# %%
train_params = collections.OrderedDict(
    epochs=250,
    lr = .001,
    
    weight_decay=0.01,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=7,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=7,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=7,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=7,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy

# %% [markdown]
# # Histogram matching - hist match

# %%
train_params = collections.OrderedDict(
    epochs=300,
    lr = .001,
    
    weight_decay=0.01,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

# %%
model, results = train_model_demo(                
                 patch_size=31,
                 temporal_width=0,
                 do_hist_match=True,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=31,
                 temporal_width=0,
                 do_hist_match=True,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=True,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=31,
                 temporal_width=0,
                 do_hist_match=True,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=True,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=True,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=True,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ### Train params comparison

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .01,
    
    weight_decay=0.01,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .01,
    
    weight_decay=0.01,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=3,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.01,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.01,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .01,
    
    weight_decay=0.1,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .01,
    
    weight_decay=0.1,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.0001,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.0001,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ## Batch Size

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024 / 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024 / 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024 * 5, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024 * 5, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024 * 6, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ## Temporal width  3 - ps 31

# %%
train_params = collections.OrderedDict(
    epochs=250,
    lr = .001,
    
    weight_decay=0.01,
    batch_size='all', # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

# %%
model, results = train_model_demo(
                 patch_size=41,
                 temporal_width=3,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=41,
                 temporal_width=3,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=45,
                 temporal_width=5,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=45,
                 temporal_width=5,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
