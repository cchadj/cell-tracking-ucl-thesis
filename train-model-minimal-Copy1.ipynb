# %%
# %load_ext autoreload
# %autoreload 2
# %autosave 5

import torch
import collections
from copy import deepcopy

from sharedvariables import get_video_sessions
from train_model import train_model_demo

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()


video_sessions_registered = get_video_sessions(should_be_registered=True, should_have_marked_cells=True)
train_params = collections.OrderedDict(
    epochs=250,
    lr = .001,
    
    weight_decay=0.01,
    batch_size=1024 * 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)
# Out:
# Autosaving every 5 seconds
# Using device: cuda

# %%
train_params = collections.OrderedDict(
    epochs=250,
    lr = .001,
    
    weight_decay=0.01,
    batch_size=1024 * 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

# %%
model, results = train_model_demo(                
                 patch_size=19,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=False,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11431, 19, 19). Non cell patches: (64705, 19, 19)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          19               0       False             False    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.885671  1.43E-04       0.360535       0.979864        0.36215       0.981156    120
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0         0.88852  1.43E-04       0.360535       0.979864        0.36215       0.981156    120
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        2048             60           20     True          60908           15228
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.4E-04   0.850348       0.000000       1.000000    2.5E-04   0.847912       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    1.5E-04   0.877652       0.217883       0.993764    1.6E-04   0.875887       0.216753       0.994114               0               0  1.00E-03               10
# 2    40    1.6E-04   0.869722       0.160395       0.994555    1.8E-04   0.866824       0.152418       0.994966               1               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.4E-04   0.887191       0.331212       0.985037    1.6E-04   0.882847       0.321675       0.983504               5               5  1.00E-03               10
# 12  240    1.5E-04   0.876223       0.207131       0.993976    1.6E-04   0.875821       0.214594       0.994424               6               6  1.00E-03               10
# 13  249    1.6E-04   0.874992       0.253538       0.984361    1.8E-04   0.874573       0.257340       0.985285               7               7  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [13:46<00:00,  3.31s/it]
# Run duration  826.9398765563965
# Saving results to directory: ./cache/models/model_va_0.886_ps_19_tw_0_mc_false_dc_true_hm_false_npp_5_st_false_da_false
# Done
#
# Model trained on 11431 cell patches and 64705 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 120
# Training accuracy:	 0.889
# Validation accuracy:	 0.886
#
# Positive train accuracy:	 0.362
# Negative train accuracy:	 0.981
#
# Positive valid accuracy:	 0.361
# Negative valid accuracy:	 0.980
#
# 0.889 0.886 0.362 0.981 0.361 0.980
# 0.889 0.886 0.362 0.981 0.361 0.980
#
# Model trained on 11431 cell patches and 64705 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 120
# Training accuracy:	 0.889
# Validation accuracy:	 0.886
#
# Positive train accuracy:	 0.362
# Negative train accuracy:	 0.981
#
# Positive valid accuracy:	 0.361
# Negative valid accuracy:	 0.980
#
# 0.889 0.886 0.362 0.981 0.361 0.980
# 0.889 0.886 0.362 0.981 0.361 0.980
# 0.8856711321250328

# %%
model, results = train_model_demo(                
                 patch_size=19,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=False,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11431, 19, 19). Non cell patches: (64649, 19, 19)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          19               0       False             False    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.888013  1.42E-04       0.322711       0.984986       0.324025       0.984727    249
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.884891  1.42E-04       0.296679       0.988682       0.300011       0.989083    249
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        2048             60           20     True          60864           15216
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.3E-04   0.848794       0.000000       1.000000    2.4E-04   0.853575       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    1.5E-04   0.870827       0.174400       0.994890    1.5E-04   0.876314       0.180880       0.995611               0               0  1.00E-03               10
# 2    40    1.5E-04   0.879436       0.258068       0.990128    1.5E-04   0.884398       0.262118       0.991146               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.5E-04   0.879420       0.288058       0.984766    1.6E-04   0.883346       0.293537       0.984524               2               2  1.00E-03               10
# 12  240    1.5E-04   0.874869       0.212974       0.992780    1.6E-04   0.877957       0.206912       0.993071               3               3  1.00E-03               10
# 13  249    1.4E-04   0.884891       0.300011       0.989083    1.5E-04   0.887355       0.296679       0.988682               0               4  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [13:47<00:00,  3.31s/it]
# Run duration  827.3816230297089
# Saving results to directory: ./cache/models/model_va_0.888_ps_19_tw_0_mc_false_dc_true_hm_false_npp_5_st_false_da_false
# Done
#
# Model trained on 11431 cell patches and 64649 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.885
# Validation accuracy:	 0.888
#
# Positive train accuracy:	 0.324
# Negative train accuracy:	 0.985
#
# Positive valid accuracy:	 0.323
# Negative valid accuracy:	 0.985
#
# 0.885 0.888 0.324 0.985 0.323 0.985
# 0.885 0.888 0.324 0.985 0.323 0.985
#
# Model trained on 11431 cell patches and 64649 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.885
# Validation accuracy:	 0.887
#
# Positive train accuracy:	 0.300
# Negative train accuracy:	 0.989
#
# Positive valid accuracy:	 0.297
# Negative valid accuracy:	 0.989
#
# 0.885 0.887 0.300 0.989 0.297 0.989
# 0.885 0.887 0.300 0.989 0.297 0.989
# 0.88801261829653

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (64305, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.901949  1.19E-04       0.474134       0.975604       0.481409       0.975152    160
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.905331  1.19E-04       0.527665       0.966233       0.548885       0.968751    160
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        2048             60           20     True          60537           15135
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.5E-04   0.848952       0.000000       1.000000    2.7E-04   0.853122       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    1.3E-04   0.894659       0.418307       0.979414    1.4E-04   0.894681       0.400810       0.979709               0               0  1.00E-03               10
# 2    40    1.3E-04   0.898508       0.461067       0.976339    1.4E-04   0.899240       0.449843       0.976611               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.2E-04   0.901977       0.549541       0.964684    1.4E-04   0.897324       0.515520       0.963058               7               2  1.00E-03               10
# 12  240    1.2E-04   0.902522       0.481518       0.977429    1.4E-04   0.901156       0.460639       0.976998               8               3  1.00E-03               10
# 13  249    1.2E-04   0.903447       0.529090       0.970054    1.4E-04   0.899174       0.503824       0.967240               9               4  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [24:10<00:00,  5.80s/it]
# Run duration  1450.9498319625854
# Saving results to directory: ./cache/models/model_va_0.902_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11367 cell patches and 64305 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.901
# Validation accuracy:	 0.902
#
# Positive train accuracy:	 0.481
# Negative train accuracy:	 0.975
#
# Positive valid accuracy:	 0.474
# Negative valid accuracy:	 0.976
#
# 0.901 0.902 0.481 0.975 0.474 0.976
# 0.901 0.902 0.481 0.975 0.474 0.976
#
# Model trained on 11367 cell patches and 64305 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.905
# Validation accuracy:	 0.902
#
# Positive train accuracy:	 0.549
# Negative train accuracy:	 0.969
#
# Positive valid accuracy:	 0.528
# Negative valid accuracy:	 0.966
#
# 0.905 0.902 0.549 0.969 0.528 0.966
# 0.905 0.902 0.549 0.969 0.528 0.966
# 0.9019491245457548

# %%
model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (64296, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.902399  1.20E-04       0.559087       0.961858       0.577576       0.961301    240
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.903948  1.20E-04       0.474038       0.973796       0.507062       0.974473    240
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        2048             60           20     True          60530           15133
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.3E-04   0.849116       0.000000       1.000000    2.4E-04   0.852376       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    1.3E-04   0.898133       0.486587       0.971263    1.4E-04   0.896187       0.461056       0.971548               0               0  1.00E-03               10
# 2    40    1.3E-04   0.898183       0.443775       0.978929    1.4E-04   0.897575       0.418532       0.980541               1               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.2E-04   0.901834       0.511442       0.971205    1.3E-04   0.899293       0.483438       0.971316               1               1  1.00E-03               10
# 12  240    1.2E-04   0.903948       0.507062       0.974473    1.3E-04   0.900020       0.474038       0.973796               2               2  1.00E-03               10
# 13  249    1.2E-04   0.900975       0.495018       0.973111    1.4E-04   0.899029       0.464190       0.974339               3               3  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [23:56<00:00,  5.75s/it]
# Run duration  1436.8220827579498
# Saving results to directory: ./cache/models/model_va_0.902_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11367 cell patches and 64296 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 200
# Training accuracy:	 0.903
# Validation accuracy:	 0.902
#
# Positive train accuracy:	 0.578
# Negative train accuracy:	 0.961
#
# Positive valid accuracy:	 0.559
# Negative valid accuracy:	 0.962
#
# 0.903 0.902 0.578 0.961 0.559 0.962
# 0.903 0.902 0.578 0.961 0.559 0.962
#
# Model trained on 11367 cell patches and 64296 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 200
# Training accuracy:	 0.904
# Validation accuracy:	 0.900
#
# Positive train accuracy:	 0.507
# Negative train accuracy:	 0.974
#
# Positive valid accuracy:	 0.474
# Negative valid accuracy:	 0.974
#
# 0.904 0.900 0.507 0.974 0.474 0.974
# 0.904 0.900 0.507 0.974 0.474 0.974
# 0.902398731249587

# %%
model, results = train_model_demo(                
                 patch_size=25,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11219, 25, 25). Non cell patches: (63473, 25, 25)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          25               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.902671  1.21E-04       0.550109       0.966335       0.569398       0.965761    249
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.906498  1.21E-04       0.550109       0.966335       0.569398       0.965761    249
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        2048             60           20     True          59753           14939
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.3E-04   0.850484       0.000000       1.000000    2.4E-04   0.847045       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    1.3E-04   0.896440       0.411574       0.981680    1.4E-04   0.893500       0.400875       0.982456               0               0  1.00E-03               10
# 2    40    1.3E-04   0.900574       0.555630       0.961215    1.4E-04   0.896579       0.546171       0.959855               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.2E-04   0.906147       0.595590       0.960743    1.3E-04   0.902336       0.580306       0.960487               0               0  1.00E-03               10
# 12  240    1.2E-04   0.902599       0.447840       0.982546    1.4E-04   0.898855       0.435449       0.982535               1               1  1.00E-03               10
# 13  249    1.2E-04   0.906498       0.569398       0.965761    1.3E-04   0.902671       0.550109       0.966335               2               0  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [24:09<00:00,  5.80s/it]
# Run duration  1449.7698428630829
# Saving results to directory: ./cache/models/model_va_0.903_ps_25_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11219 cell patches and 63473 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 249
# Training accuracy:	 0.906
# Validation accuracy:	 0.903
#
# Positive train accuracy:	 0.569
# Negative train accuracy:	 0.966
#
# Positive valid accuracy:	 0.550
# Negative valid accuracy:	 0.966
#
# 0.906 0.903 0.569 0.966 0.550 0.966
# 0.906 0.903 0.569 0.966 0.550 0.966
#
# Model trained on 11219 cell patches and 63473 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 249
# Training accuracy:	 0.906
# Validation accuracy:	 0.903
#
# Positive train accuracy:	 0.569
# Negative train accuracy:	 0.966
#
# Positive valid accuracy:	 0.550
# Negative valid accuracy:	 0.966
#
# 0.906 0.903 0.569 0.966 0.550 0.966
# 0.906 0.903 0.569 0.966 0.550 0.966
# 0.9026708615034473

# %%
model, results = train_model_demo(                
                 patch_size=25,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11219, 25, 25). Non cell patches: (63397, 25, 25)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          25               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.900764  1.19E-04       0.510936       0.971277       0.525355       0.973739    160
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.908782  1.19E-04        0.57699       0.957905        0.60103       0.962943    160
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        2048             60           20     True          59692           14924
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.2E-04   0.850348       0.000000       1.000000    2.4E-04   0.846824       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    1.3E-04   0.899551       0.472070       0.974783    1.4E-04   0.894331       0.462380       0.972464               0               0  1.00E-03               10
# 2    40    1.2E-04   0.905264       0.504646       0.975768    1.4E-04   0.900563       0.492126       0.974442               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.2E-04   0.906034       0.569573       0.965248    1.4E-04   0.897883       0.552931       0.960279               2               4  1.00E-03               10
# 12  240    1.2E-04   0.905247       0.624874       0.954589    1.4E-04   0.896744       0.609361       0.948726               0               5  1.00E-03               10
# 13  249    1.2E-04   0.905850       0.545617       0.969247    1.4E-04   0.898084       0.524934       0.965580               1               6  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [24:06<00:00,  5.79s/it]
# Run duration  1446.8139290809631
# Saving results to directory: ./cache/models/model_va_0.901_ps_25_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11219 cell patches and 63397 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 140
# Training accuracy:	 0.907
# Validation accuracy:	 0.901
#
# Positive train accuracy:	 0.525
# Negative train accuracy:	 0.974
#
# Positive valid accuracy:	 0.511
# Negative valid accuracy:	 0.971
#
# 0.907 0.901 0.525 0.974 0.511 0.971
# 0.907 0.901 0.525 0.974 0.511 0.971
#
# Model trained on 11219 cell patches and 63397 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 140
# Training accuracy:	 0.909
# Validation accuracy:	 0.900
#
# Positive train accuracy:	 0.601
# Negative train accuracy:	 0.963
#
# Positive valid accuracy:	 0.577
# Negative valid accuracy:	 0.958
#
# 0.909 0.900 0.601 0.963 0.577 0.958
# 0.909 0.900 0.601 0.963 0.577 0.958
# 0.9007638702760654

# %% [markdown]
# # Temporality - temporal patches - temporal vs no temporal

# %%
video_sessions_registered = get_video_sessions(should_be_registered=True, should_have_marked_cells=True)
train_params = collections.OrderedDict(
    epochs=250,
    lr = .001,
    
    weight_decay=0.01,
    batch_size=1024 * 5, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

# %% [markdown]
# ## Temporal width  1 - ps 21

# %%
model, results = train_model_demo(
                 patch_size=21,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10752, 21, 21, 3). Non cell patches: (60884, 21, 21, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               1       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.905849  4.89E-05       0.506086       0.975886       0.514972       0.976156    249
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.909664  4.89E-05       0.601592       0.958825       0.602252        0.96406    249
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        5120             60           20     True          57308           14328
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    1.3E-04   0.849654       0.000000       1.000000    1.3E-04   0.850921       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    5.6E-05   0.896646       0.441504       0.977183    5.6E-05   0.897753       0.448502       0.976460               0               0  1.00E-03               10
# 2    40    5.4E-05   0.895913       0.461119       0.972850    5.4E-05   0.899218       0.475187       0.973507               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    4.9E-05   0.907447       0.597493       0.962294    5.0E-05   0.903894       0.595037       0.958005               0               1  1.00E-03               10
# 12  240    4.9E-05   0.906627       0.547934       0.970098    5.0E-05   0.904243       0.543071       0.967520               1               2  1.00E-03               10
# 13  249    4.9E-05   0.909664       0.602252       0.964060    5.1E-05   0.905570       0.601592       0.958825               2               3  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [25:10<00:00,  6.04s/it]
# Run duration  1510.1559915542603
# Saving results to directory: ./cache/models/model_va_0.906_ps_21_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10752 cell patches and 60884 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 200
# Training accuracy:	 0.907
# Validation accuracy:	 0.906
#
# Positive train accuracy:	 0.515
# Negative train accuracy:	 0.976
#
# Positive valid accuracy:	 0.506
# Negative valid accuracy:	 0.976
#
# 0.907 0.906 0.515 0.976 0.506 0.976
# 0.907 0.906 0.515 0.976 0.506 0.976
#
# Model trained on 10752 cell patches and 60884 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 200
# Training accuracy:	 0.910
# Validation accuracy:	 0.906
#
# Positive train accuracy:	 0.602
# Negative train accuracy:	 0.964
#
# Positive valid accuracy:	 0.602
# Negative valid accuracy:	 0.959
#
# 0.910 0.906 0.602 0.964 0.602 0.959
# 0.910 0.906 0.602 0.964 0.602 0.959
# 0.9058486878838637

# %%
model, results = train_model_demo(
                 patch_size=21,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10752, 21, 21, 3). Non cell patches: (60868, 21, 21, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               1       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.901075  4.87E-05       0.532042       0.966927       0.549691        0.97007    240
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.908423  4.87E-05       0.549562       0.960839       0.579168       0.966436    240
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        5120             60           20     True          57296           14324
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    1.2E-04   0.850199       0.000000       1.000000    1.2E-04   0.848576       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    5.7E-05   0.897183       0.462892       0.973703    5.8E-05   0.893884       0.450438       0.973015               0               0  1.00E-03               10
# 2    40    5.4E-05   0.896293       0.585926       0.950978    5.6E-05   0.889696       0.569387       0.946853               0               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    4.9E-05   0.907096       0.549691       0.970070    5.3E-05   0.901075       0.532042       0.966927               1               0  1.00E-03               10
# 12  240    4.9E-05   0.908423       0.579168       0.966436    5.3E-05   0.898562       0.549562       0.960839               2               1  1.00E-03               10
# 13  249    4.9E-05   0.907079       0.540720       0.971630    5.2E-05   0.900307       0.512679       0.969478               3               2  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [25:08<00:00,  6.04s/it]
# Run duration  1508.8308176994324
# Saving results to directory: ./cache/models/model_va_0.901_ps_21_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10752 cell patches and 60868 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 220
# Training accuracy:	 0.907
# Validation accuracy:	 0.901
#
# Positive train accuracy:	 0.550
# Negative train accuracy:	 0.970
#
# Positive valid accuracy:	 0.532
# Negative valid accuracy:	 0.967
#
# 0.907 0.901 0.550 0.970 0.532 0.967
# 0.907 0.901 0.550 0.970 0.532 0.967
#
# Model trained on 10752 cell patches and 60868 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 220
# Training accuracy:	 0.908
# Validation accuracy:	 0.899
#
# Positive train accuracy:	 0.579
# Negative train accuracy:	 0.966
#
# Positive valid accuracy:	 0.550
# Negative valid accuracy:	 0.961
#
# 0.908 0.899 0.579 0.966 0.550 0.961
# 0.908 0.899 0.579 0.966 0.550 0.961
# 0.9010751186819325

# %% [markdown]
# ## Temporal width  1 - ps 27

# %%
model, results = train_model_demo(
                 patch_size=27,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10560, 27, 27, 3). Non cell patches: (59663, 27, 27, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          27               1       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.907868  4.15E-05       0.583837       0.966532       0.620316       0.972012    200
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.919381  4.15E-05       0.583837       0.966532       0.620316       0.972012    200
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        5120             60           20     True          56178           14045
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    1.1E-04   0.850351       0.000000       1.000000    1.2E-04   0.846707       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    5.0E-05   0.900762       0.421316       0.985137    5.6E-05   0.895835       0.405945       0.984527               0               0  1.00E-03               10
# 2    40    5.1E-05   0.896579       0.590579       0.950430    5.8E-05   0.891349       0.571296       0.949294               1               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    4.2E-05   0.916676       0.543714       0.982311    5.1E-05   0.907013       0.509057       0.979062               1               1  1.00E-03               10
# 12  240    4.5E-05   0.916818       0.597478       0.973017    5.3E-05   0.906372       0.560149       0.969055               2               2  1.00E-03               10
# 13  249    4.5E-05   0.914486       0.545141       0.979485    5.4E-05   0.903524       0.503484       0.975950               3               3  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [26:17<00:00,  6.31s/it]
# Run duration  1577.0453140735626
# Saving results to directory: ./cache/models/model_va_0.908_ps_27_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10560 cell patches and 59663 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 200
# Training accuracy:	 0.919
# Validation accuracy:	 0.908
#
# Positive train accuracy:	 0.620
# Negative train accuracy:	 0.972
#
# Positive valid accuracy:	 0.584
# Negative valid accuracy:	 0.967
#
# 0.919 0.908 0.620 0.972 0.584 0.967
# 0.919 0.908 0.620 0.972 0.584 0.967
#
# Model trained on 10560 cell patches and 59663 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 200
# Training accuracy:	 0.919
# Validation accuracy:	 0.908
#
# Positive train accuracy:	 0.620
# Negative train accuracy:	 0.972
#
# Positive valid accuracy:	 0.584
# Negative valid accuracy:	 0.967
#
# 0.919 0.908 0.620 0.972 0.584 0.967
# 0.919 0.908 0.620 0.972 0.584 0.967
# 0.9078675685297258

# %%
model, results = train_model_demo(
                 patch_size=27,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10560, 27, 27, 3). Non cell patches: (59748, 27, 27, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          27               1       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.904494  4.09E-05       0.573711       0.965546       0.622416       0.971385    240
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.919461  4.09E-05       0.573711       0.965546       0.622416       0.971385    240
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        5120             60           20     True          56246           14062
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    1.2E-04   0.843562       0.000000       0.991019    1.3E-04   0.836510       0.000000       0.990902               0               0  1.00E-03               10
# 1    20    5.2E-05   0.901113       0.573306       0.958414    5.9E-05   0.895961       0.559105       0.958133               0               0  1.00E-03               10
# 2    40    5.4E-05   0.896153       0.694946       0.931324    6.0E-05   0.890841       0.679598       0.929829               1               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    4.4E-05   0.913701       0.672243       0.955908    5.3E-05   0.901152       0.635783       0.950131               1               2  1.00E-03               10
# 12  240    4.1E-05   0.919461       0.622416       0.971385    5.1E-05   0.904494       0.573711       0.965546               0               0  1.00E-03               10
# 13  249    4.2E-05   0.917772       0.582865       0.976314    5.2E-05   0.903143       0.533090       0.971443               1               1  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [26:01<00:00,  6.24s/it]
# Run duration  1561.1174035072327
# Saving results to directory: ./cache/models/model_va_0.904_ps_27_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10560 cell patches and 59748 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 240
# Training accuracy:	 0.919
# Validation accuracy:	 0.904
#
# Positive train accuracy:	 0.622
# Negative train accuracy:	 0.971
#
# Positive valid accuracy:	 0.574
# Negative valid accuracy:	 0.966
#
# 0.919 0.904 0.622 0.971 0.574 0.966
# 0.919 0.904 0.622 0.971 0.574 0.966
#
# Model trained on 10560 cell patches and 59748 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 240
# Training accuracy:	 0.919
# Validation accuracy:	 0.904
#
# Positive train accuracy:	 0.622
# Negative train accuracy:	 0.971
#
# Positive valid accuracy:	 0.574
# Negative valid accuracy:	 0.966
#
# 0.919 0.904 0.622 0.971 0.574 0.966
# 0.919 0.904 0.622 0.971 0.574 0.966
# 0.9044943820224719

# %% [markdown]
# ## Temporal width  1 - ps 35

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=1,
                 do_hist_match=False,
    
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10444, 31, 31, 3). Non cell patches: (59026, 31, 31, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          31               1       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.907874  4.13E-05       0.543216        0.97175       0.583781       0.975701    240
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.922431  4.13E-05        0.62675       0.955933       0.690911       0.963498    240
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        5120             60           20     True          55576           13894
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    1.2E-04   0.849341       0.000000       1.000000    1.3E-04   0.850943       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    5.3E-05   0.898895       0.498985       0.969832    5.9E-05   0.898949       0.484790       0.971496               0               0  1.00E-03               10
# 2    40    4.8E-05   0.905121       0.579243       0.962926    5.4E-05   0.901540       0.552390       0.962700               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    4.1E-05   0.920289       0.602174       0.976718    5.1E-05   0.907514       0.542733       0.971412               3               3  1.00E-03               10
# 12  240    4.2E-05   0.922431       0.690911       0.963498    5.1E-05   0.906866       0.626750       0.955933               4               4  1.00E-03               10
# 13  249    4.2E-05   0.917374       0.557626       0.981188    5.1E-05   0.905499       0.504104       0.975810               5               5  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [26:37<00:00,  6.39s/it]
# Run duration  1597.8104779720306
# Saving results to directory: ./cache/models/model_va_0.908_ps_31_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10444 cell patches and 59026 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 160
# Training accuracy:	 0.917
# Validation accuracy:	 0.908
#
# Positive train accuracy:	 0.584
# Negative train accuracy:	 0.976
#
# Positive valid accuracy:	 0.543
# Negative valid accuracy:	 0.972
#
# 0.917 0.908 0.584 0.976 0.543 0.972
# 0.917 0.908 0.584 0.976 0.543 0.972
#
# Model trained on 10444 cell patches and 59026 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 160
# Training accuracy:	 0.922
# Validation accuracy:	 0.907
#
# Positive train accuracy:	 0.691
# Negative train accuracy:	 0.963
#
# Positive valid accuracy:	 0.627
# Negative valid accuracy:	 0.956
#
# 0.922 0.907 0.691 0.963 0.627 0.956
# 0.922 0.907 0.691 0.963 0.627 0.956
# 0.9078739024039154

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=1,
                 do_hist_match=False,
    
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10444, 31, 31, 3). Non cell patches: (58969, 31, 31, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          31               1       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.911258  4.06E-05       0.572457       0.971099       0.592225       0.977252    249
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.920385  4.06E-05       0.613244       0.962624       0.647608        0.96873    249
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        5120             60           20     True          55530           13883
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    1.2E-04   0.849451       0.000000       1.000000    1.3E-04   0.849888       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    5.1E-05   0.902989       0.500837       0.974263    5.7E-05   0.905136       0.523992       0.972455               0               0  1.00E-03               10
# 2    40    4.8E-05   0.901603       0.601914       0.954717    5.4E-05   0.899301       0.612284       0.949996               0               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    4.3E-05   0.914731       0.638158       0.963748    5.1E-05   0.904776       0.605086       0.957708               1               5  1.00E-03               10
# 12  240    4.2E-05   0.919287       0.592225       0.977252    5.0E-05   0.911258       0.572457       0.971099               0               0  1.00E-03               10
# 13  249    4.1E-05   0.920385       0.647608       0.968730    4.9E-05   0.910178       0.613244       0.962624               0               1  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [26:59<00:00,  6.48s/it]
# Run duration  1619.991188287735
# Saving results to directory: ./cache/models/model_va_0.911_ps_31_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10444 cell patches and 58969 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 240
# Training accuracy:	 0.919
# Validation accuracy:	 0.911
#
# Positive train accuracy:	 0.592
# Negative train accuracy:	 0.977
#
# Positive valid accuracy:	 0.572
# Negative valid accuracy:	 0.971
#
# 0.919 0.911 0.592 0.977 0.572 0.971
# 0.919 0.911 0.592 0.977 0.572 0.971
#
# Model trained on 10444 cell patches and 58969 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 240
# Training accuracy:	 0.920
# Validation accuracy:	 0.910
#
# Positive train accuracy:	 0.648
# Negative train accuracy:	 0.969
#
# Positive valid accuracy:	 0.613
# Negative valid accuracy:	 0.963
#
# 0.920 0.910 0.648 0.969 0.613 0.963
# 0.920 0.910 0.648 0.969 0.613 0.963
# 0.9112583735503854

# %% [markdown]
# ## Temporal width  1 - ps 37

# %%
model, results = train_model_demo(
                 patch_size=37,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10248, 37, 37, 3). Non cell patches: (57881, 37, 37, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          37               1       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.908337  4.03E-05       0.598653       0.964063       0.660098       0.969395    200
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.923729  4.03E-05       0.602984       0.961898       0.663892       0.969547    200
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        5120             60           20     True          54503           13626
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    1.3E-04   0.840651       0.005630       0.987892    1.4E-04   0.839131       0.005775       0.989089               0               0  1.00E-03               10
# 1    20    5.3E-05   0.902134       0.532558       0.967302    5.9E-05   0.895274       0.501444       0.966141               0               0  1.00E-03               10
# 2    40    4.7E-05   0.908152       0.604774       0.961647    5.4E-05   0.902686       0.576035       0.961465               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    4.1E-05   0.923289       0.607099       0.979043    5.2E-05   0.907897       0.544755       0.973242               1               0  1.00E-03               10
# 12  240    4.0E-05   0.923032       0.644920       0.972072    5.1E-05   0.906796       0.580366       0.965535               2               1  1.00E-03               10
# 13  249    4.1E-05   0.923032       0.660098       0.969395    5.1E-05   0.908337       0.598653       0.964063               3               0  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [28:52<00:00,  6.93s/it]
# Run duration  1732.0676681995392
# Saving results to directory: ./cache/models/model_va_0.908_ps_37_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10248 cell patches and 57881 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 249
# Training accuracy:	 0.923
# Validation accuracy:	 0.908
#
# Positive train accuracy:	 0.660
# Negative train accuracy:	 0.969
#
# Positive valid accuracy:	 0.599
# Negative valid accuracy:	 0.964
#
# 0.923 0.908 0.660 0.969 0.599 0.964
# 0.923 0.908 0.660 0.969 0.599 0.964
#
# Model trained on 10248 cell patches and 57881 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 249
# Training accuracy:	 0.924
# Validation accuracy:	 0.907
#
# Positive train accuracy:	 0.664
# Negative train accuracy:	 0.970
#
# Positive valid accuracy:	 0.603
# Negative valid accuracy:	 0.962
#
# 0.924 0.907 0.664 0.970 0.603 0.962
# 0.924 0.907 0.664 0.970 0.603 0.962
# 0.9083370027887862

# %%
model, results = train_model_demo(
                 patch_size=37,
                 temporal_width=1,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (10248, 37, 37, 3). Non cell patches: (57953, 37, 37, 3)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          37               1       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.908658  4.12E-05       0.569651       0.969962       0.624586       0.972544    200
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.922617  4.12E-05       0.603159       0.958795       0.667361       0.967501    200
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        5120             60           20     True          54560           13641
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    1.2E-04   0.850458       0.000000       1.000000    1.3E-04   0.846859       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    5.3E-05   0.902676       0.638926       0.949053    6.0E-05   0.893116       0.609382       0.944425               0               0  1.00E-03               10
# 2    40    4.9E-05   0.908431       0.608285       0.961208    5.7E-05   0.899641       0.575874       0.958189               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    4.2E-05   0.921188       0.726314       0.955454    5.2E-05   0.901913       0.654380       0.946676               0               5  1.00E-03               10
# 12  240    4.1E-05   0.922306       0.635985       0.972651    5.2E-05   0.906605       0.577788       0.966066               0               0  1.00E-03               10
# 13  249    4.2E-05   0.920510       0.624586       0.972544    5.2E-05   0.908658       0.569651       0.969962               1               0  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [29:06<00:00,  6.98s/it]
# Run duration  1746.020542383194
# Saving results to directory: ./cache/models/model_va_0.909_ps_37_tw_1_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 10248 cell patches and 57953 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 249
# Training accuracy:	 0.921
# Validation accuracy:	 0.909
#
# Positive train accuracy:	 0.625
# Negative train accuracy:	 0.973
#
# Positive valid accuracy:	 0.570
# Negative valid accuracy:	 0.970
#
# 0.921 0.909 0.625 0.973 0.570 0.970
# 0.921 0.909 0.625 0.973 0.570 0.970
#
# Model trained on 10248 cell patches and 57953 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 249
# Training accuracy:	 0.923
# Validation accuracy:	 0.904
#
# Positive train accuracy:	 0.667
# Negative train accuracy:	 0.968
#
# Positive valid accuracy:	 0.603
# Negative valid accuracy:	 0.959
#
# 0.923 0.904 0.667 0.968 0.603 0.959
# 0.923 0.904 0.667 0.968 0.603 0.959
# 0.9086577230408328

# %% [markdown]
# ## Temporal width 2 - 31

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=2,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (9670, 31, 31, 5). Non cell patches: (54674, 31, 31, 5)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          31               2       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0          0.8557  7.48E-05       0.051901       0.998901       0.049974       0.998377    120
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.856163  7.48E-05       0.061665       0.996521       0.065381       0.995772    120
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        5120             60           20     True          51475           12869
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    1.4E-04   0.836192       0.021103       0.980092    1.6E-04   0.833864       0.017986       0.979218               0               0  1.00E-03               10
# 1    20    1.1E-04   0.849947       0.000000       1.000000    1.2E-04   0.848784       0.000000       1.000000               0               0  1.00E-03               10
# 2    40    8.8E-05   0.849947       0.000000       1.000000    9.6E-05   0.848784       0.000000       1.000000               0               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    7.6E-05   0.853152       0.022657       0.999771    8.3E-05   0.852281       0.023638       0.999908               6               5  1.00E-03               10
# 12  240    7.9E-05   0.853599       0.033532       0.998377    8.7E-05   0.852514       0.033402       0.998444               7               6  1.00E-03               10
# 13  249    7.5E-05   0.856066       0.049974       0.998377    8.3E-05   0.855700       0.051901       0.998901               8               0  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [24:46<00:00,  5.95s/it]
# Run duration  1486.50754404068
# Saving results to directory: ./cache/models/model_va_0.856_ps_31_tw_2_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9670 cell patches and 54674 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 249
# Training accuracy:	 0.856
# Validation accuracy:	 0.856
#
# Positive train accuracy:	 0.050
# Negative train accuracy:	 0.998
#
# Positive valid accuracy:	 0.052
# Negative valid accuracy:	 0.999
#
# 0.856 0.856 0.050 0.998 0.052 0.999
# 0.856 0.856 0.050 0.998 0.052 0.999
#
# Model trained on 9670 cell patches and 54674 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 249
# Training accuracy:	 0.856
# Validation accuracy:	 0.855
#
# Positive train accuracy:	 0.065
# Negative train accuracy:	 0.996
#
# Positive valid accuracy:	 0.062
# Negative valid accuracy:	 0.997
#
# 0.856 0.855 0.065 0.996 0.062 0.997
# 0.856 0.855 0.065 0.996 0.062 0.997
# 0.8556997435698189

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=2,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (9670, 31, 31, 5). Non cell patches: (54644, 31, 31, 5)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          31               2       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.865661  7.22E-05       0.156627       0.989228        0.14895       0.989837    200
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.863093  7.22E-05       0.128339       0.993153       0.124082       0.994369    200
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        5120             60           20     True          51451           12863
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    1.3E-04   0.849157       0.000000       1.000000    1.4E-04   0.851590       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    8.8E-05   0.850829       0.011081       1.000000    9.6E-05   0.853300       0.011524       1.000000               0               0  1.00E-03               10
# 2    40    8.2E-05   0.850693       0.010179       1.000000    8.9E-05   0.852911       0.008905       1.000000               0               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    7.4E-05   0.862996       0.148950       0.989837    8.1E-05   0.865661       0.156627       0.989228               1               0  1.00E-03               10
# 12  240    7.6E-05   0.860838       0.138384       0.989174    8.4E-05   0.864262       0.144054       0.989775               2               1  1.00E-03               10
# 13  249    7.7E-05   0.858526       0.090066       0.995033    8.3E-05   0.861230       0.090100       0.995618               3               2  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [25:09<00:00,  6.04s/it]
# Run duration  1509.6425187587738
# Saving results to directory: ./cache/models/model_va_0.866_ps_31_tw_2_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9670 cell patches and 54644 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 220
# Training accuracy:	 0.863
# Validation accuracy:	 0.866
#
# Positive train accuracy:	 0.149
# Negative train accuracy:	 0.990
#
# Positive valid accuracy:	 0.157
# Negative valid accuracy:	 0.989
#
# 0.863 0.866 0.149 0.990 0.157 0.989
# 0.863 0.866 0.149 0.990 0.157 0.989
#
# Model trained on 9670 cell patches and 54644 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 220
# Training accuracy:	 0.863
# Validation accuracy:	 0.865
#
# Positive train accuracy:	 0.124
# Negative train accuracy:	 0.994
#
# Positive valid accuracy:	 0.128
# Negative valid accuracy:	 0.993
#
# 0.863 0.865 0.124 0.994 0.128 0.993
# 0.863 0.865 0.124 0.994 0.128 0.993
# 0.8656611987872191

# %% [markdown]
# ## Temporal width 2 - 35

# %%
model, results = train_model_demo(
                 patch_size=35,
                 temporal_width=2,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (9541, 35, 35, 5). Non cell patches: (53910, 35, 35, 5)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          35               2       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.872902  6.30E-05       0.254622       0.981293       0.278896       0.981397    220
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.875552  6.30E-05       0.254622       0.981293       0.278896       0.981397    220
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        5120             60           20     True          50760           12691
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    1.3E-04   0.847045       0.000000       0.997309    1.6E-04   0.847845       0.000000       0.996481               0               0  1.00E-03               10
# 1    20    8.2E-05   0.849330       0.000000       1.000000    9.9E-05   0.850839       0.000000       1.000000               0               0  1.00E-03               10
# 2    40    7.0E-05   0.850827       0.018175       0.998539    8.5E-05   0.852179       0.015848       0.998796               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    6.3E-05   0.875552       0.278896       0.981397    7.8E-05   0.872902       0.254622       0.981293               1               0  1.00E-03               10
# 12  240    6.6E-05   0.866548       0.160303       0.991835    8.1E-05   0.866204       0.145272       0.992591               2               1  1.00E-03               10
# 13  249    6.3E-05   0.861643       0.104733       0.995918    7.8E-05   0.861871       0.100370       0.995370               0               2  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [25:48<00:00,  6.20s/it]
# Run duration  1548.7967367172241
# Saving results to directory: ./cache/models/model_va_0.873_ps_35_tw_2_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9541 cell patches and 53910 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 220
# Training accuracy:	 0.876
# Validation accuracy:	 0.873
#
# Positive train accuracy:	 0.279
# Negative train accuracy:	 0.981
#
# Positive valid accuracy:	 0.255
# Negative valid accuracy:	 0.981
#
# 0.876 0.873 0.279 0.981 0.255 0.981
# 0.876 0.873 0.279 0.981 0.255 0.981
#
# Model trained on 9541 cell patches and 53910 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 220
# Training accuracy:	 0.876
# Validation accuracy:	 0.873
#
# Positive train accuracy:	 0.279
# Negative train accuracy:	 0.981
#
# Positive valid accuracy:	 0.255
# Negative valid accuracy:	 0.981
#
# 0.876 0.873 0.279 0.981 0.255 0.981
# 0.876 0.873 0.279 0.981 0.255 0.981
# 0.872902056575526

# %%
model, results = train_model_demo(
                 patch_size=35,
                 temporal_width=2,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (9541, 35, 35, 5). Non cell patches: (53935, 35, 35, 5)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          35               2       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.872873  6.08E-05       0.234516       0.984455       0.254443       0.984279    249
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.878338  6.08E-05       0.255691       0.980568        0.30149       0.980685    249
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     250        5120             60           20     True          50780           12696
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    1.4E-04   0.210358       0.924726       0.083612    1.7E-04   0.209909       0.932239       0.083649               0               0  1.00E-03               10
# 1    20    7.5E-05   0.849311       0.000000       1.000000    8.8E-05   0.851213       0.000000       1.000000               0               0  1.00E-03               10
# 2    40    7.2E-05   0.849409       0.000653       1.000000    8.4E-05   0.851213       0.000000       1.000000               0               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    6.2E-05   0.868275       0.162180       0.993554    7.6E-05   0.867281       0.148227       0.992968               0               2  1.00E-03               10
# 12  240    6.5E-05   0.871997       0.219420       0.987781    7.8E-05   0.869959       0.193753       0.988156               1               3  1.00E-03               10
# 13  249    6.1E-05   0.878338       0.301490       0.980685    7.4E-05   0.872716       0.255691       0.980568               0               4  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [25:27<00:00,  6.11s/it]
# Run duration  1527.9775686264038
# Saving results to directory: ./cache/models/model_va_0.873_ps_35_tw_2_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9541 cell patches and 53935 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.874
# Validation accuracy:	 0.873
#
# Positive train accuracy:	 0.254
# Negative train accuracy:	 0.984
#
# Positive valid accuracy:	 0.235
# Negative valid accuracy:	 0.984
#
# 0.874 0.873 0.254 0.984 0.235 0.984
# 0.874 0.873 0.254 0.984 0.235 0.984
#
# Model trained on 9541 cell patches and 53935 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.878
# Validation accuracy:	 0.873
#
# Positive train accuracy:	 0.301
# Negative train accuracy:	 0.981
#
# Positive valid accuracy:	 0.256
# Negative valid accuracy:	 0.981
#
# 0.878 0.873 0.301 0.981 0.256 0.981
# 0.878 0.873 0.301 0.981 0.256 0.981
# 0.8728733459357277

# %% [markdown]
# # Patchsizes comparison 15 vs 23 - patch size comparison

# %%
video_sessions_registered = get_video_sessions(should_be_registered=True, should_have_marked_cells=True)
train_params = collections.OrderedDict(
    epochs=200,
    lr = .001,
    
    weight_decay=0.01,
    batch_size=1024 * 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

# %% [markdown]
# ## Patch size 15

# %%
model, results = train_model_demo(                
                 patch_size=15,
                 
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11556, 15, 15). Non cell patches: (65422, 15, 15)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          15               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.892505  1.35E-04       0.450085       0.971958        0.44746       0.973057    120
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.894433  1.35E-04       0.450085       0.971958        0.44746       0.973057    120
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     200        2048             60           20     True          61582           15396
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.1E-04   0.850427       0.000109       1.000000    2.2E-04   0.847753       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    1.5E-04   0.878227       0.225033       0.993126    1.6E-04   0.874643       0.213737       0.993334               0               0  1.00E-03               10
# 2    40    1.4E-04   0.887451       0.366804       0.979034    1.5E-04   0.886139       0.372014       0.978471               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 8   160    1.3E-04   0.893508       0.472210       0.967615    1.4E-04   0.891076       0.475683       0.965676               0               2  1.00E-03               10
# 9   180    1.4E-04   0.889578       0.356383       0.983368    1.5E-04   0.889452       0.367747       0.983144               1               3  1.00E-03               10
# 10  199    1.4E-04   0.893216       0.525402       0.957915    1.4E-04   0.890491       0.526877       0.955792               2               4  1.00E-03               10
#
# [11 rows x 13 columns]
# 100%|██████████| 200/200 [19:11<00:00,  5.76s/it]
# Run duration  1151.9752521514893
# Saving results to directory: ./cache/models/model_va_0.893_ps_15_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11556 cell patches and 65422 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 120
# Training accuracy:	 0.894
# Validation accuracy:	 0.893
#
# Positive train accuracy:	 0.447
# Negative train accuracy:	 0.973
#
# Positive valid accuracy:	 0.450
# Negative valid accuracy:	 0.972
#
# 0.894 0.893 0.447 0.973 0.450 0.972
# 0.894 0.893 0.447 0.973 0.450 0.972
#
# Model trained on 11556 cell patches and 65422 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 120
# Training accuracy:	 0.894
# Validation accuracy:	 0.893
#
# Positive train accuracy:	 0.447
# Negative train accuracy:	 0.973
#
# Positive valid accuracy:	 0.450
# Negative valid accuracy:	 0.972
#
# 0.894 0.893 0.447 0.973 0.450 0.972
# 0.894 0.893 0.447 0.973 0.450 0.972
# 0.8925045466354897

# %%
model, results = train_model_demo(                
                 patch_size=15,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11556, 15, 15). Non cell patches: (65501, 15, 15)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          15               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.896899  1.35E-04       0.506874       0.963746       0.495646       0.965001    160
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.894184  1.35E-04       0.506874       0.963746       0.495646       0.965001    160
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     200        2048             60           20     True          61645           15412
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.3E-04   0.849120       0.000000       1.000000    2.3E-04   0.853685       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    1.4E-04   0.887679       0.467262       0.962383    1.5E-04   0.890151       0.480710       0.960325               0               0  1.00E-03               10
# 2    40    1.4E-04   0.888977       0.399849       0.975890    1.4E-04   0.891967       0.405322       0.975374               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 8   160    1.4E-04   0.894184       0.495646       0.965001    1.4E-04   0.896899       0.506874       0.963746               0               0  1.00E-03               10
# 9   180    1.4E-04   0.888880       0.351790       0.984315    1.4E-04   0.890670       0.356984       0.982139               1               1  1.00E-03               10
# 10  199    1.4E-04   0.892773       0.429094       0.975164    1.4E-04   0.894303       0.437251       0.972638               2               2  1.00E-03               10
#
# [11 rows x 13 columns]
# 100%|██████████| 200/200 [19:01<00:00,  5.71s/it]
# Run duration  1141.8959376811981
# Saving results to directory: ./cache/models/model_va_0.897_ps_15_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11556 cell patches and 65501 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 160
# Training accuracy:	 0.894
# Validation accuracy:	 0.897
#
# Positive train accuracy:	 0.496
# Negative train accuracy:	 0.965
#
# Positive valid accuracy:	 0.507
# Negative valid accuracy:	 0.964
#
# 0.894 0.897 0.496 0.965 0.507 0.964
# 0.894 0.897 0.496 0.965 0.507 0.964
#
# Model trained on 11556 cell patches and 65501 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 160
# Training accuracy:	 0.894
# Validation accuracy:	 0.897
#
# Positive train accuracy:	 0.496
# Negative train accuracy:	 0.965
#
# Positive valid accuracy:	 0.507
# Negative valid accuracy:	 0.964
#
# 0.894 0.897 0.496 0.965 0.507 0.964
# 0.894 0.897 0.496 0.965 0.507 0.964
# 0.8968985206332728

# %% [markdown]
# ## Patch size 17

# %%
model, results = train_model_demo(                
                 patch_size=17,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11485, 17, 17). Non cell patches: (64993, 17, 17)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          17               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.897555  1.27E-04       0.525022       0.964093       0.523181       0.963088    199
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.899317  1.27E-04       0.528041        0.96286       0.538562       0.962895    199
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     200        2048             60           20     True          61182           15296
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.6E-04   0.850168       0.000000       1.000000    2.8E-04   0.848457       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    1.3E-04   0.892991       0.402858       0.979371    1.4E-04   0.894155       0.401208       0.982201               0               0  1.00E-03               10
# 2    40    1.3E-04   0.892011       0.411258       0.976737    1.4E-04   0.893698       0.418033       0.978656               0               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 8   160    1.3E-04   0.897731       0.476274       0.972008    1.4E-04   0.895855       0.475410       0.970951               0               5  1.00E-03               10
# 9   180    1.4E-04   0.887745       0.627686       0.933577    1.5E-04   0.888271       0.634599       0.933580               1               6  1.00E-03               10
# 10  199    1.3E-04   0.899317       0.538562       0.962895    1.4E-04   0.896967       0.528041       0.962860               2               7  1.00E-03               10
#
# [11 rows x 13 columns]
# 100%|██████████| 200/200 [19:25<00:00,  5.83s/it]
# Run duration  1165.1637496948242
# Saving results to directory: ./cache/models/model_va_0.898_ps_17_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11485 cell patches and 64993 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 60
# Training accuracy:	 0.897
# Validation accuracy:	 0.898
#
# Positive train accuracy:	 0.523
# Negative train accuracy:	 0.963
#
# Positive valid accuracy:	 0.525
# Negative valid accuracy:	 0.964
#
# 0.897 0.898 0.523 0.963 0.525 0.964
# 0.897 0.898 0.523 0.963 0.525 0.964
#
# Model trained on 11485 cell patches and 64993 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 60
# Training accuracy:	 0.899
# Validation accuracy:	 0.897
#
# Positive train accuracy:	 0.539
# Negative train accuracy:	 0.963
#
# Positive valid accuracy:	 0.528
# Negative valid accuracy:	 0.963
#
# 0.899 0.897 0.539 0.963 0.528 0.963
# 0.899 0.897 0.539 0.963 0.528 0.963
# 0.8975549163179917

# %%
model, results = train_model_demo(                
                 patch_size=17,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11485, 17, 17). Non cell patches: (65029, 17, 17)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          17               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.896622  1.26E-04       0.482198        0.96899       0.489794       0.970366    180
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.899904  1.26E-04       0.461538       0.971446        0.47861        0.97452    180
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     200        2048             60           20     True          61211           15303
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.4E-04   0.849537       0.000000       1.000000    2.6E-04   0.851336       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    1.3E-04   0.894104       0.475353       0.968270    1.4E-04   0.892766       0.468571       0.966841               0               0  1.00E-03               10
# 2    40    1.3E-04   0.892519       0.380347       0.983231    1.4E-04   0.889629       0.366154       0.981041               1               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 8   160    1.3E-04   0.895705       0.405863       0.982462    1.4E-04   0.893942       0.397363       0.980657               3               3  1.00E-03               10
# 9   180    1.3E-04   0.899904       0.478610       0.974520    1.4E-04   0.895641       0.461538       0.971446               4               4  1.00E-03               10
# 10  199    1.3E-04   0.899446       0.496200       0.970866    1.4E-04   0.895249       0.478242       0.968069               5               5  1.00E-03               10
#
# [11 rows x 13 columns]
# 100%|██████████| 200/200 [19:21<00:00,  5.81s/it]
# Run duration  1161.965090751648
# Saving results to directory: ./cache/models/model_va_0.897_ps_17_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11485 cell patches and 65029 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 100
# Training accuracy:	 0.898
# Validation accuracy:	 0.897
#
# Positive train accuracy:	 0.490
# Negative train accuracy:	 0.970
#
# Positive valid accuracy:	 0.482
# Negative valid accuracy:	 0.969
#
# 0.898 0.897 0.490 0.970 0.482 0.969
# 0.898 0.897 0.490 0.970 0.482 0.969
#
# Model trained on 11485 cell patches and 65029 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 100
# Training accuracy:	 0.900
# Validation accuracy:	 0.896
#
# Positive train accuracy:	 0.479
# Negative train accuracy:	 0.975
#
# Positive valid accuracy:	 0.462
# Negative valid accuracy:	 0.971
#
# 0.900 0.896 0.479 0.975 0.462 0.971
# 0.900 0.896 0.479 0.975 0.462 0.971
# 0.8966215774684703

# %% [markdown]
# ## Patch Size 25

# %%
model, results = train_model_demo(                
                 patch_size=25,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11219, 25, 25). Non cell patches: (63455, 25, 25)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          25               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.905725  1.21E-04       0.554281       0.968585       0.550653       0.969736    140
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.906928  1.21E-04       0.554281       0.968585       0.550653       0.969736    140
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     200        2048             60           20     True          59739           14935
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.3E-04   0.850131       0.000000       1.000000    2.4E-04   0.848276       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    1.3E-04   0.900266       0.507986       0.969421    1.4E-04   0.901707       0.525596       0.968979               0               0  1.00E-03               10
# 2    40    1.2E-04   0.902610       0.495253       0.974422    1.4E-04   0.902645       0.507061       0.973400               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 8   160    1.3E-04   0.901036       0.643360       0.946462    1.4E-04   0.896485       0.635481       0.943168               1               1  1.00E-03               10
# 9   180    1.2E-04   0.905439       0.607059       0.958040    1.4E-04   0.902578       0.608120       0.955245               2               2  1.00E-03               10
# 10  199    1.2E-04   0.903514       0.586619       0.959379    1.3E-04   0.901975       0.584289       0.958797               0               3  1.00E-03               10
#
# [11 rows x 13 columns]
# 100%|██████████| 200/200 [20:15<00:00,  6.08s/it]
# Run duration  1215.0086860656738
# Saving results to directory: ./cache/models/model_va_0.906_ps_25_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11219 cell patches and 63455 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 140
# Training accuracy:	 0.907
# Validation accuracy:	 0.906
#
# Positive train accuracy:	 0.551
# Negative train accuracy:	 0.970
#
# Positive valid accuracy:	 0.554
# Negative valid accuracy:	 0.969
#
# 0.907 0.906 0.551 0.970 0.554 0.969
# 0.907 0.906 0.551 0.970 0.554 0.969
#
# Model trained on 11219 cell patches and 63455 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 140
# Training accuracy:	 0.907
# Validation accuracy:	 0.906
#
# Positive train accuracy:	 0.551
# Negative train accuracy:	 0.970
#
# Positive valid accuracy:	 0.554
# Negative valid accuracy:	 0.969
#
# 0.907 0.906 0.551 0.970 0.554 0.969
# 0.907 0.906 0.551 0.970 0.554 0.969
# 0.9057248074991631

# %%
model, results = train_model_demo(                
                 patch_size=25,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11219, 25, 25). Non cell patches: (63527, 25, 25)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          25               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.904615  1.18E-04       0.540063        0.96782       0.551165       0.969421    180
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0        0.907786  1.18E-04        0.52603       0.968684       0.550388       0.971193    180
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03  0.01     200        2048             60           20     True          59796           14950
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.8E-04   0.849321       0.000000       1.000000    3.0E-04   0.852241       0.000000       1.000000               0               0  1.00E-03               10
# 1    20    1.3E-04   0.899375       0.566149       0.958492    1.4E-04   0.898462       0.552739       0.958402               0               0  1.00E-03               10
# 2    40    1.3E-04   0.897167       0.658380       0.939531    1.4E-04   0.894247       0.648257       0.936897               0               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 8   160    1.2E-04   0.907435       0.515871       0.976903    1.3E-04   0.903144       0.488909       0.974963               5               4  1.00E-03               10
# 9   180    1.2E-04   0.907786       0.550388       0.971193    1.3E-04   0.903278       0.526030       0.968684               6               5  1.00E-03               10
# 10  199    1.2E-04   0.903238       0.580799       0.960442    1.4E-04   0.901003       0.564962       0.959265               7               6  1.00E-03               10
#
# [11 rows x 13 columns]
# 100%|██████████| 200/200 [19:20<00:00,  5.80s/it]
# Run duration  1160.4236249923706
# Saving results to directory: ./cache/models/model_va_0.905_ps_25_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11219 cell patches and 63527 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 80
# Training accuracy:	 0.906
# Validation accuracy:	 0.905
#
# Positive train accuracy:	 0.551
# Negative train accuracy:	 0.969
#
# Positive valid accuracy:	 0.540
# Negative valid accuracy:	 0.968
#
# 0.906 0.905 0.551 0.969 0.540 0.968
# 0.906 0.905 0.551 0.969 0.540 0.968
#
# Model trained on 11219 cell patches and 63527 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 80
# Training accuracy:	 0.908
# Validation accuracy:	 0.903
#
# Positive train accuracy:	 0.550
# Negative train accuracy:	 0.971
#
# Positive valid accuracy:	 0.526
# Negative valid accuracy:	 0.969
#
# 0.908 0.903 0.550 0.971 0.526 0.969
# 0.908 0.903 0.550 0.971 0.526 0.969
# 0.9046153846153846

# %% [markdown]
# ### Mixed Channel Patches

# %%
train_params = collections.OrderedDict(
    epochs=250,
    lr = .001,
    
    weight_decay=0.01,
    batch_size=1024 * 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

# %% [markdown]
# ## mc - ps 19 - dc

# %%
model, results = train_model_demo(
                 patch_size=19,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy
# Out:
# 'Cell patches: (9439, 19, 19, 2). Non cell patches: (53781, 19, 19, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          19               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.905  1.18E-04          0.554          0.967          0.548          0.969    120
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.906  1.18E-04          0.561          0.965          0.554          0.968    120
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     250        2048             60           20     True          50576           12644
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.8E-04      0.851          0.000          1.000    3.2E-04      0.851          0.000          1.000               0               0  1.00E-03               10
# 1    20    1.3E-04      0.896          0.402          0.983    1.4E-04      0.898          0.424          0.981               0               0  1.00E-03               10
# 2    40    1.3E-04      0.890          0.320          0.990    1.5E-04      0.893          0.339          0.990               1               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.3E-04      0.901          0.505          0.971    1.4E-04      0.900          0.502          0.970               1               5  1.00E-03               10
# 12  240    1.2E-04      0.905          0.512          0.974    1.4E-04      0.905          0.521          0.972               2               6  1.00E-03               10
# 13  249    1.2E-04      0.906          0.548          0.969    1.3E-04      0.905          0.554          0.967               0               0  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [21:25<00:00,  5.14s/it]
# Run duration  1285.891995191574
# Saving results to directory: ./cache/models/model_va_0.905_ps_19_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9439 cell patches and 53781 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 249
# Training accuracy:	 0.906
# Validation accuracy:	 0.905
#
# Positive train accuracy:	 0.548
# Negative train accuracy:	 0.969
#
# Positive valid accuracy:	 0.554
# Negative valid accuracy:	 0.967
#
# 0.906 0.905 0.548 0.969 0.554 0.967
# 0.906 0.905 0.548 0.969 0.554 0.967
#
# Model trained on 9439 cell patches and 53781 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 249
# Training accuracy:	 0.906
# Validation accuracy:	 0.905
#
# Positive train accuracy:	 0.554
# Negative train accuracy:	 0.968
#
# Positive valid accuracy:	 0.561
# Negative valid accuracy:	 0.965
#
# 0.906 0.905 0.554 0.968 0.561 0.965
# 0.906 0.905 0.554 0.968 0.561 0.965
# 0.9050933248971844

# %%
model, results = train_model_demo(
                 patch_size=19,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy
# Out:
# 'Cell patches: (9439, 19, 19, 2). Non cell patches: (53753, 19, 19, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          19               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.906  1.20E-04          0.528          0.971          0.529          0.971    180
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.905  1.20E-04          0.528          0.971          0.529          0.971    180
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     250        2048             60           20     True          50553           12639
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.6E-04      0.850          0.000          1.000    2.9E-04      0.853          0.000          1.000               0               0  1.00E-03               10
# 1    20    1.3E-04      0.896          0.429          0.978    1.5E-04      0.896          0.424          0.978               0               0  1.00E-03               10
# 2    40    1.3E-04      0.898          0.448          0.977    1.4E-04      0.899          0.444          0.977               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.2E-04      0.904          0.535          0.969    1.4E-04      0.900          0.515          0.967               2               2  1.00E-03               10
# 12  240    1.2E-04      0.904          0.548          0.967    1.4E-04      0.901          0.537          0.964               3               3  1.00E-03               10
# 13  249    1.2E-04      0.902          0.575          0.960    1.4E-04      0.901          0.569          0.959               4               4  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [21:28<00:00,  5.16s/it]
# Run duration  1288.879369020462
# Saving results to directory: ./cache/models/model_va_0.906_ps_19_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9439 cell patches and 53753 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.905
# Validation accuracy:	 0.906
#
# Positive train accuracy:	 0.529
# Negative train accuracy:	 0.971
#
# Positive valid accuracy:	 0.528
# Negative valid accuracy:	 0.971
#
# 0.905 0.906 0.529 0.971 0.528 0.971
# 0.905 0.906 0.529 0.971 0.528 0.971
#
# Model trained on 9439 cell patches and 53753 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.905
# Validation accuracy:	 0.906
#
# Positive train accuracy:	 0.529
# Negative train accuracy:	 0.971
#
# Positive valid accuracy:	 0.528
# Negative valid accuracy:	 0.971
#
# 0.905 0.906 0.529 0.971 0.528 0.971
# 0.905 0.906 0.529 0.971 0.528 0.971
# 0.905926101748556

# %% [markdown]
# ## mc - ps 21 - dc - 21 Aug

# %%
model, results = train_model_demo(
                 patch_size=21,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy
# Out:
# 'Cell patches: (9375, 21, 21, 2). Non cell patches: (53362, 21, 21, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.902  1.17E-04          0.534          0.967          0.567          0.969    180
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.909  1.17E-04          0.534          0.967          0.567          0.969    180
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     250        2048             60           20     True          50189           12548
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.4E-04      0.850          0.000          1.000    2.7E-04      0.851          0.000          1.000               0               0  1.00E-03               10
# 1    20    1.3E-04      0.895          0.435          0.976    1.5E-04      0.893          0.424          0.976               0               0  1.00E-03               10
# 2    40    1.3E-04      0.893          0.344          0.989    1.5E-04      0.891          0.336          0.989               1               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.2E-04      0.905          0.478          0.981    1.4E-04      0.901          0.448          0.980               2               2  1.00E-03               10
# 12  240    1.2E-04      0.905          0.516          0.973    1.4E-04      0.900          0.486          0.972               3               3  1.00E-03               10
# 13  249    1.2E-04      0.906          0.524          0.973    1.4E-04      0.900          0.496          0.970               4               4  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [21:31<00:00,  5.16s/it]
# Run duration  1291.22913980484
# Saving results to directory: ./cache/models/model_va_0.902_ps_21_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9375 cell patches and 53362 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.909
# Validation accuracy:	 0.902
#
# Positive train accuracy:	 0.567
# Negative train accuracy:	 0.969
#
# Positive valid accuracy:	 0.534
# Negative valid accuracy:	 0.967
#
# 0.909 0.902 0.567 0.969 0.534 0.967
# 0.909 0.902 0.567 0.969 0.534 0.967
#
# Model trained on 9375 cell patches and 53362 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.909
# Validation accuracy:	 0.902
#
# Positive train accuracy:	 0.567
# Negative train accuracy:	 0.969
#
# Positive valid accuracy:	 0.534
# Negative valid accuracy:	 0.967
#
# 0.909 0.902 0.567 0.969 0.534 0.967
# 0.909 0.902 0.567 0.969 0.534 0.967
# 0.9023748804590372

# %%
model, results = train_model_demo(
                 patch_size=21,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy
# Out:
# 'Cell patches: (9375, 21, 21, 2). Non cell patches: (53293, 21, 21, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.904  1.18E-04          0.553          0.966          0.544          0.968    200
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.908  1.18E-04          0.559          0.965          0.568          0.967    200
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     250        2048             60           20     True          50134           12534
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.7E-04      0.851          0.000          1.000    3.0E-04      0.850          0.000          1.000               0               0  1.00E-03               10
# 1    20    1.3E-04      0.898          0.560          0.957    1.4E-04      0.899          0.585          0.955               0               0  1.00E-03               10
# 2    40    1.3E-04      0.901          0.530          0.966    1.4E-04      0.901          0.542          0.965               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.2E-04      0.905          0.544          0.968    1.4E-04      0.904          0.553          0.966               0               0  1.00E-03               10
# 12  240    1.2E-04      0.904          0.587          0.960    1.4E-04      0.902          0.591          0.957               0               1  1.00E-03               10
# 13  249    1.2E-04      0.907          0.583          0.963    1.4E-04      0.902          0.567          0.961               0               2  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [21:33<00:00,  5.17s/it]
# Run duration  1293.633529663086
# Saving results to directory: ./cache/models/model_va_0.904_ps_21_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9375 cell patches and 53293 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 220
# Training accuracy:	 0.905
# Validation accuracy:	 0.904
#
# Positive train accuracy:	 0.544
# Negative train accuracy:	 0.968
#
# Positive valid accuracy:	 0.553
# Negative valid accuracy:	 0.966
#
# 0.905 0.904 0.544 0.968 0.553 0.966
# 0.905 0.904 0.544 0.968 0.553 0.966
#
# Model trained on 9375 cell patches and 53293 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 220
# Training accuracy:	 0.908
# Validation accuracy:	 0.904
#
# Positive train accuracy:	 0.568
# Negative train accuracy:	 0.967
#
# Positive valid accuracy:	 0.559
# Negative valid accuracy:	 0.965
#
# 0.908 0.904 0.568 0.967 0.559 0.965
# 0.908 0.904 0.568 0.967 0.559 0.965
# 0.9042604116802297

# %% [markdown]
# ## mc - ps 25 - dc - 21 Aug

# %%
model, results = train_model_demo(
                 patch_size=25,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy
# Out:
# 'Cell patches: (9235, 25, 25, 2). Non cell patches: (52347, 25, 25, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          25               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.908  1.19E-04          0.562          0.967          0.579          0.967    100
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.908  1.19E-04          0.569          0.964          0.589          0.965    100
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     250        2048             60           20     True          49265           12317
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.9E-04      0.849          0.000          1.000    3.2E-04      0.854          0.000          1.000               0               0  1.00E-03               10
# 1    20    1.3E-04      0.900          0.457          0.979    1.4E-04      0.902          0.456          0.978               0               0  1.00E-03               10
# 2    40    1.3E-04      0.894          0.354          0.990    1.4E-04      0.896          0.345          0.990               1               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.2E-04      0.905          0.639          0.952    1.4E-04      0.901          0.614          0.951               5               1  1.00E-03               10
# 12  240    1.2E-04      0.904          0.529          0.971    1.3E-04      0.902          0.508          0.970               6               2  1.00E-03               10
# 13  249    1.2E-04      0.904          0.638          0.952    1.4E-04      0.901          0.610          0.951               7               3  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [21:51<00:00,  5.25s/it]
# Run duration  1311.9226214885712
# Saving results to directory: ./cache/models/model_va_0.908_ps_25_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9235 cell patches and 52347 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 200
# Training accuracy:	 0.908
# Validation accuracy:	 0.908
#
# Positive train accuracy:	 0.579
# Negative train accuracy:	 0.967
#
# Positive valid accuracy:	 0.562
# Negative valid accuracy:	 0.967
#
# 0.908 0.908 0.579 0.967 0.562 0.967
# 0.908 0.908 0.579 0.967 0.562 0.967
#
# Model trained on 9235 cell patches and 52347 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 200
# Training accuracy:	 0.908
# Validation accuracy:	 0.907
#
# Positive train accuracy:	 0.589
# Negative train accuracy:	 0.965
#
# Positive valid accuracy:	 0.569
# Negative valid accuracy:	 0.964
#
# 0.908 0.907 0.589 0.965 0.569 0.964
# 0.908 0.907 0.589 0.965 0.569 0.964
# 0.9075261833238614

# %%
model, results = train_model_demo(
                 patch_size=25,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy
# Out:
# 'Cell patches: (9235, 25, 25, 2). Non cell patches: (52434, 25, 25, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          25               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.909  1.19E-04          0.523          0.977          0.533          0.976    140
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.910  1.19E-04          0.573          0.967          0.584          0.968    140
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     250        2048             60           20     True          49335           12334
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.4E-04      0.850          0.000          1.000    2.7E-04      0.850          0.000          1.000               0               0  1.00E-03               10
# 1    20    1.3E-04      0.902          0.485          0.975    1.5E-04      0.900          0.478          0.975               0               0  1.00E-03               10
# 2    40    1.3E-04      0.896          0.382          0.987    1.6E-04      0.896          0.375          0.988               1               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.2E-04      0.904          0.587          0.960    1.5E-04      0.902          0.565          0.962               6               4  1.00E-03               10
# 12  240    1.2E-04      0.910          0.533          0.976    1.4E-04      0.909          0.523          0.977               0               0  1.00E-03               10
# 13  249    1.2E-04      0.901          0.410          0.988    1.5E-04      0.896          0.383          0.986               1               1  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [21:52<00:00,  5.25s/it]
# Run duration  1312.9007875919342
# Saving results to directory: ./cache/models/model_va_0.909_ps_25_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9235 cell patches and 52434 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 240
# Training accuracy:	 0.910
# Validation accuracy:	 0.909
#
# Positive train accuracy:	 0.533
# Negative train accuracy:	 0.976
#
# Positive valid accuracy:	 0.523
# Negative valid accuracy:	 0.977
#
# 0.910 0.909 0.533 0.976 0.523 0.977
# 0.910 0.909 0.533 0.976 0.523 0.977
#
# Model trained on 9235 cell patches and 52434 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 240
# Training accuracy:	 0.910
# Validation accuracy:	 0.908
#
# Positive train accuracy:	 0.584
# Negative train accuracy:	 0.968
#
# Positive valid accuracy:	 0.573
# Negative valid accuracy:	 0.967
#
# 0.910 0.908 0.584 0.968 0.573 0.967
# 0.910 0.908 0.584 0.968 0.573 0.967
# 0.9091940976163451

# %% [markdown]
# ## mc - ps 27 - dc

# %%
model, results = train_model_demo(
                 patch_size=27,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy
# Out:
# 'Cell patches: (9176, 27, 27, 2). Non cell patches: (52050, 27, 27, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          27               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.909  1.08E-04          0.579          0.967          0.602          0.967    180
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.913  1.08E-04          0.521          0.976          0.546          0.977    180
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     250        2048             60           20     True          48980           12246
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.5E-04      0.850          0.000          1.000    2.5E-04      0.850          0.000          1.000               0               0  1.00E-03               10
# 1    20    1.3E-04      0.900          0.584          0.955    1.3E-04      0.897          0.565          0.956               0               0  1.00E-03               10
# 2    40    1.3E-04      0.901          0.643          0.947    1.3E-04      0.897          0.628          0.945               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.1E-04      0.912          0.635          0.961    1.2E-04      0.906          0.601          0.960               1               1  1.00E-03               10
# 12  240    1.1E-04      0.910          0.604          0.964    1.2E-04      0.906          0.576          0.964               2               2  1.00E-03               10
# 13  249    1.1E-04      0.910          0.579          0.969    1.2E-04      0.905          0.556          0.967               3               3  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [21:59<00:00,  5.28s/it]
# Run duration  1319.9687201976776
# Saving results to directory: ./cache/models/model_va_0.909_ps_27_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9176 cell patches and 52050 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 200
# Training accuracy:	 0.913
# Validation accuracy:	 0.909
#
# Positive train accuracy:	 0.602
# Negative train accuracy:	 0.967
#
# Positive valid accuracy:	 0.579
# Negative valid accuracy:	 0.967
#
# 0.913 0.909 0.602 0.967 0.579 0.967
# 0.913 0.909 0.602 0.967 0.579 0.967
#
# Model trained on 9176 cell patches and 52050 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 200
# Training accuracy:	 0.913
# Validation accuracy:	 0.908
#
# Positive train accuracy:	 0.546
# Negative train accuracy:	 0.977
#
# Positive valid accuracy:	 0.521
# Negative valid accuracy:	 0.976
#
# 0.913 0.908 0.546 0.977 0.521 0.976
# 0.913 0.908 0.546 0.977 0.521 0.976
# 0.9087865425445043

# %%
model, results = train_model_demo(
                 patch_size=27,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy
# Out:
# 'Cell patches: (9176, 27, 27, 2). Non cell patches: (52001, 27, 27, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          27               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.909  1.08E-04          0.570          0.967          0.591          0.971    220
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.913  1.08E-04          0.570          0.967          0.591          0.971    220
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     250        2048             60           20     True          48941           12236
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.7E-04      0.849          0.000          1.000    2.7E-04      0.854          0.000          1.000               0               0  1.00E-03               10
# 1    20    1.2E-04      0.901          0.522          0.968    1.3E-04      0.900          0.515          0.966               0               0  1.00E-03               10
# 2    40    1.2E-04      0.903          0.474          0.979    1.2E-04      0.905          0.474          0.978               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.1E-04      0.913          0.591          0.971    1.1E-04      0.909          0.570          0.967               0               0  1.00E-03               10
# 12  240    1.1E-04      0.910          0.584          0.969    1.2E-04      0.907          0.559          0.966               1               1  1.00E-03               10
# 13  249    1.1E-04      0.912          0.567          0.973    1.1E-04      0.909          0.546          0.971               2               2  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [21:58<00:00,  5.27s/it]
# Run duration  1318.1158714294434
# Saving results to directory: ./cache/models/model_va_0.909_ps_27_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9176 cell patches and 52001 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 220
# Training accuracy:	 0.913
# Validation accuracy:	 0.909
#
# Positive train accuracy:	 0.591
# Negative train accuracy:	 0.971
#
# Positive valid accuracy:	 0.570
# Negative valid accuracy:	 0.967
#
# 0.913 0.909 0.591 0.971 0.570 0.967
# 0.913 0.909 0.591 0.971 0.570 0.967
#
# Model trained on 9176 cell patches and 52001 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 220
# Training accuracy:	 0.913
# Validation accuracy:	 0.909
#
# Positive train accuracy:	 0.591
# Negative train accuracy:	 0.971
#
# Positive valid accuracy:	 0.570
# Negative valid accuracy:	 0.967
#
# 0.913 0.909 0.591 0.971 0.570 0.967
# 0.913 0.909 0.591 0.971 0.570 0.967
# 0.9088754494932985

# %% [markdown]
# ## mc - ps 31 - dc - 21 Aug

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy
# Out:
# 'Cell patches: (9033, 31, 31, 2). Non cell patches: (51133, 31, 31, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          31               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.906  1.07E-04          0.566          0.965          0.612          0.970    249
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.918  1.07E-04          0.585          0.962          0.642          0.967    249
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     250        2048             60           20     True          48132           12034
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.3E-04      0.849          0.000          1.000    2.3E-04      0.853          0.000          1.000               0               0  1.00E-03               10
# 1    20    1.3E-04      0.898          0.404          0.986    1.3E-04      0.895          0.381          0.984               0               0  1.00E-03               10
# 2    40    1.2E-04      0.903          0.463          0.982    1.3E-04      0.899          0.421          0.982               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.3E-04      0.902          0.463          0.980    1.3E-04      0.894          0.413          0.977               2               3  1.00E-03               10
# 12  240    1.1E-04      0.913          0.555          0.977    1.2E-04      0.903          0.495          0.973               3               4  1.00E-03               10
# 13  249    1.1E-04      0.918          0.642          0.967    1.2E-04      0.906          0.585          0.962               0               5  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [22:13<00:00,  5.33s/it]
# Run duration  1333.7212398052216
# Saving results to directory: ./cache/models/model_va_0.906_ps_31_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9033 cell patches and 51133 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 160
# Training accuracy:	 0.916
# Validation accuracy:	 0.906
#
# Positive train accuracy:	 0.612
# Negative train accuracy:	 0.970
#
# Positive valid accuracy:	 0.566
# Negative valid accuracy:	 0.965
#
# 0.916 0.906 0.612 0.970 0.566 0.965
# 0.916 0.906 0.612 0.970 0.566 0.965
#
# Model trained on 9033 cell patches and 51133 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 160
# Training accuracy:	 0.918
# Validation accuracy:	 0.906
#
# Positive train accuracy:	 0.642
# Negative train accuracy:	 0.967
#
# Positive valid accuracy:	 0.585
# Negative valid accuracy:	 0.962
#
# 0.918 0.906 0.642 0.967 0.585 0.962
# 0.918 0.906 0.642 0.967 0.585 0.962
# 0.9062655808542464

# %%
model, results = train_model_demo(
                 patch_size=31,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy
# Out:
# 'Cell patches: (9033, 31, 31, 2). Non cell patches: (51147, 31, 31, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          31               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.908  1.12E-04          0.562          0.966          0.592          0.973    240
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.915  1.12E-04          0.562          0.966          0.592          0.973    240
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     250        2048             60           20     True          48144           12036
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.6E-04      0.849          0.000          1.000    2.6E-04      0.855          0.000          1.000               0               0  1.00E-03               10
# 1    20    1.3E-04      0.899          0.552          0.961    1.3E-04      0.897          0.546          0.957               0               0  1.00E-03               10
# 2    40    1.2E-04      0.908          0.534          0.974    1.2E-04      0.904          0.520          0.969               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.2E-04      0.910          0.682          0.951    1.2E-04      0.902          0.653          0.944               2               3  1.00E-03               10
# 12  240    1.1E-04      0.915          0.592          0.973    1.2E-04      0.908          0.562          0.966               0               0  1.00E-03               10
# 13  249    1.2E-04      0.906          0.468          0.984    1.2E-04      0.900          0.440          0.978               1               1  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [22:17<00:00,  5.35s/it]
# Run duration  1337.1762716770172
# Saving results to directory: ./cache/models/model_va_0.908_ps_31_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9033 cell patches and 51147 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 240
# Training accuracy:	 0.915
# Validation accuracy:	 0.908
#
# Positive train accuracy:	 0.592
# Negative train accuracy:	 0.973
#
# Positive valid accuracy:	 0.562
# Negative valid accuracy:	 0.966
#
# 0.915 0.908 0.592 0.973 0.562 0.966
# 0.915 0.908 0.592 0.973 0.562 0.966
#
# Model trained on 9033 cell patches and 51147 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 240
# Training accuracy:	 0.915
# Validation accuracy:	 0.908
#
# Positive train accuracy:	 0.592
# Negative train accuracy:	 0.973
#
# Positive valid accuracy:	 0.562
# Negative valid accuracy:	 0.966
#
# 0.915 0.908 0.592 0.973 0.562 0.966
# 0.915 0.908 0.592 0.973 0.562 0.966
# 0.9076935859089399

# %% [markdown]
# ## mc - ps 35 - dc - 21 Aug

# %%
model, results = train_model_demo(
                 patch_size=35,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy
# Out:
# 'Cell patches: (8880, 35, 35, 2). Non cell patches: (50287, 35, 35, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          35               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.908  1.19E-04          0.566          0.968          0.577          0.970    200
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.911  1.19E-04          0.515          0.973          0.535          0.978    200
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     250        2048             60           20     True          47333           11834
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    3.1E-04      0.850          0.000          1.000    3.1E-04      0.851          0.000          1.000               0               0  1.00E-03               10
# 1    20    2.2E-04      0.850          0.000          1.000    2.1E-04      0.851          0.000          1.000               0               1  1.00E-03               10
# 2    40    1.4E-04      0.850          0.000          1.000    1.4E-04      0.851          0.000          1.000               0               2  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.2E-04      0.910          0.600          0.965    1.3E-04      0.907          0.591          0.962               2               2  1.00E-03               10
# 12  240    1.2E-04      0.909          0.505          0.980    1.2E-04      0.906          0.499          0.977               3               3  1.00E-03               10
# 13  249    1.2E-04      0.907          0.502          0.979    1.3E-04      0.904          0.491          0.976               4               4  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [22:40<00:00,  5.44s/it]
# Run duration  1360.3895056247711
# Saving results to directory: ./cache/models/model_va_0.908_ps_35_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 8880 cell patches and 50287 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.911
# Validation accuracy:	 0.908
#
# Positive train accuracy:	 0.577
# Negative train accuracy:	 0.970
#
# Positive valid accuracy:	 0.566
# Negative valid accuracy:	 0.968
#
# 0.911 0.908 0.577 0.970 0.566 0.968
# 0.911 0.908 0.577 0.970 0.566 0.968
#
# Model trained on 8880 cell patches and 50287 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 180
# Training accuracy:	 0.911
# Validation accuracy:	 0.905
#
# Positive train accuracy:	 0.535
# Negative train accuracy:	 0.978
#
# Positive valid accuracy:	 0.515
# Negative valid accuracy:	 0.973
#
# 0.911 0.905 0.535 0.978 0.515 0.973
# 0.911 0.905 0.535 0.978 0.515 0.973
# 0.9082305222241001

# %%
model, results = train_model_demo(
                 patch_size=35,
                 temporal_width=0,

                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
    
                 dataset_to_grayscale=False,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),
    
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                 v=True, vv=True)
results.best_valid_accuracy
# Out:
# 'Cell patches: (8880, 35, 35, 2). Non cell patches: (50303, 35, 35, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          35               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.909  1.18E-04          0.608          0.961          0.628          0.962    140
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.912  1.18E-04          0.608          0.961          0.628          0.962    140
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     250        2048             60           20     True          47346           11837
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.7E-04      0.849          0.000          1.000    2.7E-04      0.853          0.000          1.000               0               0  1.00E-03               10
# 1    20    2.3E-04      0.849          0.000          1.000    2.3E-04      0.853          0.000          1.000               0               1  1.00E-03               10
# 2    40    1.5E-04      0.849          0.000          1.000    1.5E-04      0.853          0.000          1.000               0               2  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 11  220    1.3E-04      0.908          0.664          0.951    1.3E-04      0.903          0.637          0.949               1               4  1.00E-03               10
# 12  240    1.2E-04      0.907          0.508          0.978    1.2E-04      0.908          0.498          0.979               2               5  1.00E-03               10
# 13  249    1.2E-04      0.907          0.588          0.963    1.2E-04      0.905          0.556          0.965               3               6  1.00E-03               10
#
# [14 rows x 13 columns]
# 100%|██████████| 250/250 [22:38<00:00,  5.43s/it]
# Run duration  1358.5627808570862
# Saving results to directory: ./cache/models/model_va_0.909_ps_35_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 8880 cell patches and 50303 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 140
# Training accuracy:	 0.912
# Validation accuracy:	 0.909
#
# Positive train accuracy:	 0.628
# Negative train accuracy:	 0.962
#
# Positive valid accuracy:	 0.608
# Negative valid accuracy:	 0.961
#
# 0.912 0.909 0.628 0.962 0.608 0.961
# 0.912 0.909 0.628 0.962 0.608 0.961
#
# Model trained on 8880 cell patches and 50303 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 140
# Training accuracy:	 0.912
# Validation accuracy:	 0.909
#
# Positive train accuracy:	 0.628
# Negative train accuracy:	 0.962
#
# Positive valid accuracy:	 0.608
# Negative valid accuracy:	 0.961
#
# 0.912 0.909 0.628 0.962 0.608 0.961
# 0.912 0.909 0.628 0.962 0.608 0.961
# 0.9094365126298893

# %% [markdown]
# ### Train params comparison

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .01,
    
    weight_decay=0.01,
    batch_size=1024 * 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (64339, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.892  1.41E-04          0.521          0.957          0.535          0.955    480
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.893  1.41E-04          0.515          0.955          0.536          0.956    480
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     500        2048             60           20     True          60564           15142
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.1E-04      0.850          0.000          1.000    2.3E-04      0.850          0.000          1.000               0               0  1.00E-02               10
# 1    20    1.6E-04      0.850          0.000          1.000    1.7E-04      0.850          0.000          1.000               0               1  1.00E-02               10
# 2    40    1.5E-04      0.850          0.000          1.000    1.6E-04      0.850          0.000          1.000               0               2  1.00E-02               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 23  460    1.4E-04      0.889          0.556          0.948    1.6E-04      0.886          0.539          0.947               1               1  1.00E-03               10
# 24  480    1.4E-04      0.893          0.536          0.956    1.5E-04      0.889          0.515          0.955               0               2  1.00E-03               10
# 25  499    1.4E-04      0.892          0.535          0.955    1.5E-04      0.892          0.521          0.957               0               0  1.00E-03               10
#
# [26 rows x 13 columns]
# 100%|██████████| 500/500 [47:43<00:00,  5.73s/it]
# Run duration  2863.8890268802643
# Saving results to directory: ./cache/models/model_va_0.892_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11367 cell patches and 64339 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 499
# Training accuracy:	 0.892
# Validation accuracy:	 0.892
#
# Positive train accuracy:	 0.535
# Negative train accuracy:	 0.955
#
# Positive valid accuracy:	 0.521
# Negative valid accuracy:	 0.957
#
# 0.892 0.892 0.535 0.955 0.521 0.957
# 0.892 0.892 0.535 0.955 0.521 0.957
#
# Model trained on 11367 cell patches and 64339 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 499
# Training accuracy:	 0.893
# Validation accuracy:	 0.889
#
# Positive train accuracy:	 0.536
# Negative train accuracy:	 0.956
#
# Positive valid accuracy:	 0.515
# Negative valid accuracy:	 0.955
#
# 0.893 0.889 0.536 0.956 0.515 0.955
# 0.893 0.889 0.536 0.956 0.515 0.955
# 0.8917580240390965

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .01,
    
    weight_decay=0.01,
    batch_size=1024 * 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=3,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (42654, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    3
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.862  1.77E-04          0.509          0.955          0.504          0.953    460
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.862  1.77E-04          0.628          0.923          0.620          0.926    460
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.010     500        2048             60           20     True          43216           10805
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.7E-04      0.789          0.000          1.000    2.9E-04      0.793          0.000          1.000               0               0  1.00E-02               10
# 1    20    1.9E-04      0.851          0.409          0.969    2.0E-04      0.855          0.419          0.969               0               0  1.00E-02               10
# 2    40    1.9E-04      0.856          0.507          0.950    2.0E-04      0.861          0.516          0.952               1               0  1.00E-02               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 23  460    1.8E-04      0.862          0.620          0.926    1.9E-04      0.862          0.628          0.923               0              17  1.00E-03               10
# 24  480    1.8E-04      0.855          0.668          0.905    2.0E-04      0.853          0.672          0.901               1              18  1.00E-03               10
# 25  499    1.8E-04      0.859          0.631          0.919    1.9E-04      0.858          0.633          0.917               0              19  1.00E-03               10
#
# [26 rows x 13 columns]
# 100%|██████████| 500/500 [34:21<00:00,  4.12s/it]
# Run duration  2061.3974058628082
# Saving results to directory: ./cache/models/model_va_0.862_ps_21_tw_0_mc_false_dc_true_hm_false_npp_3_st_true_da_false
# Done
#
# Model trained on 11367 cell patches and 42654 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 120
# Training accuracy:	 0.858
# Validation accuracy:	 0.862
#
# Positive train accuracy:	 0.504
# Negative train accuracy:	 0.953
#
# Positive valid accuracy:	 0.509
# Negative valid accuracy:	 0.955
#
# 0.858 0.862 0.504 0.953 0.509 0.955
# 0.858 0.862 0.504 0.953 0.509 0.955
#
# Model trained on 11367 cell patches and 42654 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 120
# Training accuracy:	 0.862
# Validation accuracy:	 0.862
#
# Positive train accuracy:	 0.620
# Negative train accuracy:	 0.926
#
# Positive valid accuracy:	 0.628
# Negative valid accuracy:	 0.923
#
# 0.862 0.862 0.620 0.926 0.628 0.923
# 0.862 0.862 0.620 0.926 0.628 0.923
# 0.8622859787135585

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.01,
    batch_size=1024 * 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (64289, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.905  1.03E-04          0.576          0.965          0.620          0.971    499
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.918  1.03E-04          0.576          0.965          0.620          0.971    499
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-04 0.010     500        2048             60           20     True          60524           15132
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.3E-04      0.851          0.000          1.000    2.4E-04      0.847          0.000          1.000               0               0  1.00E-03               10
# 1    20    1.3E-04      0.898          0.448          0.977    1.4E-04      0.897          0.454          0.978               0               0  1.00E-03               10
# 2    40    1.3E-04      0.899          0.571          0.957    1.4E-04      0.897          0.578          0.954               1               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 23  460    1.1E-04      0.915          0.659          0.960    1.3E-04      0.902          0.615          0.954               1               1  1.00E-04               10
# 24  480    1.1E-04      0.917          0.638          0.966    1.2E-04      0.905          0.595          0.961               0               2  1.00E-04               10
# 25  499    1.0E-04      0.918          0.620          0.971    1.2E-04      0.905          0.576          0.965               1               0  1.00E-04               10
#
# [26 rows x 13 columns]
# 100%|██████████| 500/500 [47:48<00:00,  5.74s/it]
# Run duration  2868.676295042038
# Saving results to directory: ./cache/models/model_va_0.905_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11367 cell patches and 64289 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 499
# Training accuracy:	 0.918
# Validation accuracy:	 0.905
#
# Positive train accuracy:	 0.620
# Negative train accuracy:	 0.971
#
# Positive valid accuracy:	 0.576
# Negative valid accuracy:	 0.965
#
# 0.918 0.905 0.620 0.971 0.576 0.965
# 0.918 0.905 0.620 0.971 0.576 0.965
#
# Model trained on 11367 cell patches and 64289 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 499
# Training accuracy:	 0.918
# Validation accuracy:	 0.905
#
# Positive train accuracy:	 0.620
# Negative train accuracy:	 0.971
#
# Positive valid accuracy:	 0.576
# Negative valid accuracy:	 0.965
#
# 0.918 0.905 0.620 0.971 0.576 0.965
# 0.918 0.905 0.620 0.971 0.576 0.965
# 0.9054321966693101

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.01,
    batch_size=1024 * 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (64310, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.908  1.03E-04          0.592          0.964          0.625          0.970    499
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.918  1.03E-04          0.592          0.964          0.625          0.970    499
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-04 0.010     500        2048             60           20     True          60541           15136
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.1E-04      0.850          0.000          1.000    2.3E-04      0.849          0.000          1.000               0               0  1.00E-03               10
# 1    20    1.3E-04      0.896          0.418          0.980    1.4E-04      0.892          0.407          0.979               0               0  1.00E-03               10
# 2    40    1.3E-04      0.898          0.571          0.956    1.4E-04      0.894          0.554          0.955               1               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 23  460    1.1E-04      0.914          0.625          0.965    1.2E-04      0.905          0.595          0.961               0               1  1.00E-04               10
# 24  480    1.1E-04      0.918          0.650          0.965    1.3E-04      0.906          0.602          0.960               1               0  1.00E-04               10
# 25  499    1.0E-04      0.918          0.625          0.970    1.2E-04      0.908          0.592          0.964               0               0  1.00E-04               10
#
# [26 rows x 13 columns]
# 100%|██████████| 500/500 [47:40<00:00,  5.72s/it]
# Run duration  2860.7807219028473
# Saving results to directory: ./cache/models/model_va_0.908_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11367 cell patches and 64310 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 499
# Training accuracy:	 0.918
# Validation accuracy:	 0.908
#
# Positive train accuracy:	 0.625
# Negative train accuracy:	 0.970
#
# Positive valid accuracy:	 0.592
# Negative valid accuracy:	 0.964
#
# 0.918 0.908 0.625 0.970 0.592 0.964
# 0.918 0.908 0.625 0.970 0.592 0.964
#
# Model trained on 11367 cell patches and 64310 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 499
# Training accuracy:	 0.918
# Validation accuracy:	 0.908
#
# Positive train accuracy:	 0.625
# Negative train accuracy:	 0.970
#
# Positive valid accuracy:	 0.592
# Negative valid accuracy:	 0.964
#
# 0.918 0.908 0.625 0.970 0.592 0.964
# 0.918 0.908 0.625 0.970 0.592 0.964
# 0.9080998942917548

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .01,
    
    weight_decay=0.1,
    batch_size=1024 * 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (64349, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.845  2.14E-04          0.000          1.000          0.000          1.000      0
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.851  2.14E-04          0.000          1.000          0.000          1.000      0
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.100     500        2048             60           20     True          60572           15144
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.2E-04      0.851          0.000          1.000    2.4E-04      0.845          0.000          1.000               0               0  1.00E-02               10
# 1    20    2.2E-04      0.851          0.000          1.000    2.3E-04      0.845          0.000          1.000               0               1  1.00E-02               10
# 2    40    2.2E-04      0.851          0.000          1.000    2.3E-04      0.845          0.000          1.000               1               2  1.00E-02               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 23  460    2.2E-04      0.851          0.000          1.000    2.3E-04      0.845          0.000          1.000              15              23  1.00E-03               10
# 24  480    2.2E-04      0.851          0.000          1.000    2.3E-04      0.845          0.000          1.000              16              24  1.00E-03               10
# 25  499    2.2E-04      0.851          0.000          1.000    2.3E-04      0.845          0.000          1.000              17              25  1.00E-03               10
#
# [26 rows x 13 columns]
# 100%|██████████| 500/500 [48:37<00:00,  5.84s/it]
# Run duration  2917.620591402054
# Saving results to directory: ./cache/models/model_va_0.845_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11367 cell patches and 64349 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 0
# Training accuracy:	 0.851
# Validation accuracy:	 0.845
#
# Positive train accuracy:	 0.000
# Negative train accuracy:	 1.000
#
# Positive valid accuracy:	 0.000
# Negative valid accuracy:	 1.000
#
# 0.851 0.845 0.000 1.000 0.000 1.000
# 0.851 0.845 0.000 1.000 0.000 1.000
#
# Model trained on 11367 cell patches and 64349 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 0
# Training accuracy:	 0.851
# Validation accuracy:	 0.845
#
# Positive train accuracy:	 0.000
# Negative train accuracy:	 1.000
#
# Positive valid accuracy:	 0.000
# Negative valid accuracy:	 1.000
#
# 0.851 0.845 0.000 1.000 0.000 1.000
# 0.851 0.845 0.000 1.000 0.000 1.000
# 0.8452192287374538

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .01,
    
    weight_decay=0.1,
    batch_size=1024 * 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (64321, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.855  2.16E-04          0.000          1.000          0.000          1.000      0
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.849  2.16E-04          0.000          1.000          0.000          1.000      0
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-03 0.100     500        2048             60           20     True          60550           15138
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.3E-04      0.849          0.000          1.000    2.4E-04      0.855          0.000          1.000               0               0  1.00E-02               10
# 1    20    2.2E-04      0.849          0.000          1.000    2.3E-04      0.855          0.000          1.000               0               1  1.00E-02               10
# 2    40    2.2E-04      0.849          0.000          1.000    2.3E-04      0.855          0.000          1.000               1               2  1.00E-02               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 23  460    2.2E-04      0.849          0.000          1.000    2.3E-04      0.855          0.000          1.000               5              23  1.00E-03               10
# 24  480    2.2E-04      0.849          0.000          1.000    2.3E-04      0.855          0.000          1.000               6              24  1.00E-03               10
# 25  499    2.2E-04      0.849          0.000          1.000    2.3E-04      0.855          0.000          1.000               7              25  1.00E-03               10
#
# [26 rows x 13 columns]
# 100%|██████████| 500/500 [48:31<00:00,  5.82s/it]
# Run duration  2911.0778572559357
# Saving results to directory: ./cache/models/model_va_0.855_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11367 cell patches and 64321 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 0
# Training accuracy:	 0.849
# Validation accuracy:	 0.855
#
# Positive train accuracy:	 0.000
# Negative train accuracy:	 1.000
#
# Positive valid accuracy:	 0.000
# Negative valid accuracy:	 1.000
#
# 0.849 0.855 0.000 1.000 0.000 1.000
# 0.849 0.855 0.000 1.000 0.000 1.000
#
# Model trained on 11367 cell patches and 64321 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 0
# Training accuracy:	 0.849
# Validation accuracy:	 0.855
#
# Positive train accuracy:	 0.000
# Negative train accuracy:	 1.000
#
# Positive valid accuracy:	 0.000
# Negative valid accuracy:	 1.000
#
# 0.849 0.855 0.000 1.000 0.000 1.000
# 0.849 0.855 0.000 1.000 0.000 1.000
# 0.8547364248910028

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.0001,
    batch_size=1024 * 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (64272, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.903  6.17E-05          0.598          0.959          0.790          0.983    499
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.954  6.17E-05          0.598          0.959          0.790          0.983    499
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-04 0.000     500        2048             60           20     True          60511           15128
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.9E-04      0.764          0.138          0.873    3.1E-04      0.761          0.133          0.877               0               0  1.00E-03               10
# 1    20    1.2E-04      0.900          0.601          0.952    1.4E-04      0.890          0.578          0.947               0               0  1.00E-03               10
# 2    40    1.2E-04      0.903          0.625          0.952    1.3E-04      0.894          0.602          0.948               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 23  460    6.5E-05      0.951          0.786          0.979    1.3E-04      0.901          0.603          0.956              15              10  1.00E-04               10
# 24  480    6.3E-05      0.952          0.791          0.981    1.3E-04      0.902          0.604          0.957              16              11  1.00E-04               10
# 25  499    6.2E-05      0.954          0.790          0.983    1.3E-04      0.903          0.598          0.959              17               0  1.00E-04               10
#
# [26 rows x 13 columns]
# 100%|██████████| 500/500 [48:19<00:00,  5.80s/it]
# Run duration  2899.7416026592255
# Saving results to directory: ./cache/models/model_va_0.903_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11367 cell patches and 64272 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 499
# Training accuracy:	 0.954
# Validation accuracy:	 0.903
#
# Positive train accuracy:	 0.790
# Negative train accuracy:	 0.983
#
# Positive valid accuracy:	 0.598
# Negative valid accuracy:	 0.959
#
# 0.954 0.903 0.790 0.983 0.598 0.959
# 0.954 0.903 0.790 0.983 0.598 0.959
#
# Model trained on 11367 cell patches and 64272 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 499
# Training accuracy:	 0.954
# Validation accuracy:	 0.903
#
# Positive train accuracy:	 0.790
# Negative train accuracy:	 0.983
#
# Positive valid accuracy:	 0.598
# Negative valid accuracy:	 0.959
#
# 0.954 0.903 0.790 0.983 0.598 0.959
# 0.954 0.903 0.790 0.983 0.598 0.959
# 0.9026308831306187

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.0001,
    batch_size=1024 * 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (11367, 21, 21). Non cell patches: (64312, 21, 21)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.907  6.15E-05          0.594          0.962          0.745          0.977    499
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.955  6.15E-05          0.608          0.958          0.821          0.979    499
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-04 0.000     500        2048             60           20     True          60543           15136
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    2.9E-04      0.849          0.001          0.999    3.1E-04      0.849          0.002          0.999               0               0  1.00E-03               10
# 1    20    1.2E-04      0.899          0.597          0.952    1.4E-04      0.896          0.580          0.952               0               0  1.00E-03               10
# 2    40    1.2E-04      0.903          0.614          0.954    1.3E-04      0.897          0.592          0.951               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 23  460    6.4E-05      0.952          0.805          0.978    1.3E-04      0.905          0.603          0.959              14               2  1.00E-04               10
# 24  480    6.3E-05      0.953          0.807          0.979    1.3E-04      0.906          0.605          0.959              15               3  1.00E-04               10
# 25  499    6.1E-05      0.955          0.821          0.979    1.3E-04      0.905          0.608          0.958              16               4  1.00E-04               10
#
# [26 rows x 13 columns]
# 100%|██████████| 500/500 [48:26<00:00,  5.81s/it]
# Run duration  2906.96391582489
# Saving results to directory: ./cache/models/model_va_0.907_ps_21_tw_0_mc_false_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 11367 cell patches and 64312 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 420
# Training accuracy:	 0.942
# Validation accuracy:	 0.907
#
# Positive train accuracy:	 0.745
# Negative train accuracy:	 0.977
#
# Positive valid accuracy:	 0.594
# Negative valid accuracy:	 0.962
#
# 0.942 0.907 0.745 0.977 0.594 0.962
# 0.942 0.907 0.745 0.977 0.594 0.962
#
# Model trained on 11367 cell patches and 64312 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 420
# Training accuracy:	 0.955
# Validation accuracy:	 0.905
#
# Positive train accuracy:	 0.821
# Negative train accuracy:	 0.979
#
# Positive valid accuracy:	 0.608
# Negative valid accuracy:	 0.958
#
# 0.955 0.905 0.821 0.979 0.608 0.958
# 0.955 0.905 0.821 0.979 0.608 0.958
# 0.9067785412262156

# %% [markdown]
# ## Batch Size

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (9375, 21, 21, 2). Non cell patches: (53334, 21, 21, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.910  1.35E-04          0.641          0.956          0.785          0.976    499
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.948  1.35E-04          0.641          0.956          0.785          0.976    499
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-04 0.001     500        1024             60           20     True          50167           12542
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    4.1E-04      0.850          0.000          1.000    4.3E-04      0.852          0.000          1.000               0               0  1.00E-03               10
# 1    20    2.3E-04      0.905          0.567          0.964    2.6E-04      0.904          0.568          0.963               0               0  1.00E-03               10
# 2    40    2.2E-04      0.910          0.581          0.967    2.4E-04      0.904          0.565          0.963               0               1  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 23  460    1.5E-04      0.943          0.755          0.976    2.4E-04      0.909          0.633          0.957               1               7  1.00E-04               10
# 24  480    1.4E-04      0.946          0.801          0.972    2.4E-04      0.907          0.659          0.950               2               8  1.00E-04               10
# 25  499    1.4E-04      0.948          0.785          0.976    2.4E-04      0.910          0.641          0.956               3               0  1.00E-04               10
#
# [26 rows x 13 columns]
# 100%|██████████| 500/500 [44:23<00:00,  5.33s/it]
# Run duration  2663.1207795143127
# Saving results to directory: ./cache/models/model_va_0.910_ps_21_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9375 cell patches and 53334 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 499
# Training accuracy:	 0.948
# Validation accuracy:	 0.910
#
# Positive train accuracy:	 0.785
# Negative train accuracy:	 0.976
#
# Positive valid accuracy:	 0.641
# Negative valid accuracy:	 0.956
#
# 0.948 0.910 0.785 0.976 0.641 0.956
# 0.948 0.910 0.785 0.976 0.641 0.956
#
# Model trained on 9375 cell patches and 53334 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 499
# Training accuracy:	 0.948
# Validation accuracy:	 0.910
#
# Positive train accuracy:	 0.785
# Negative train accuracy:	 0.976
#
# Positive valid accuracy:	 0.641
# Negative valid accuracy:	 0.956
#
# 0.948 0.910 0.785 0.976 0.641 0.956
# 0.948 0.910 0.785 0.976 0.641 0.956
# 0.9097432626375379

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
# 'Cell patches: (9375, 21, 21, 2). Non cell patches: (53365, 21, 21, 2)'
# 'Training new model.'
# 'You can interrupt(ctr - C or interrupt kernel in notebook) any time to get the model with the best validation accuracy at the current time.'
#    patch size  temporal width  hist match  standardize data  nnp
# 0          21               0       False              True    5
#    Best valid acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.909  1.87E-04          0.610          0.961          0.661          0.968    499
#    Best train acc      loss  valid pos acc  valid neg acc  train pos acc  train neg acc  epoch
# 0           0.923  1.87E-04          0.630          0.957          0.684          0.965    499
#          lr    wd  epochs  batch_size  stop patience  lr patience  shuffle  Trainset size  Validset size
# 0  1.00E-04 0.001     500        1024             60           20     True          50192           12548
#       e train loss  train acc  train pos acc  train neg acc valid loss  valid acc  valid pos acc  valid neg acc  lst bst loss e  lst bst acc  e        lr  evaluate_epochs
# 0     0    4.5E-04      0.851          0.000          1.000    4.7E-04      0.851          0.000          1.000               0               0  1.00E-03               10
# 1    20    2.5E-04      0.902          0.537          0.966    2.6E-04      0.901          0.535          0.965               0               0  1.00E-03               10
# 2    40    2.4E-04      0.905          0.556          0.967    2.5E-04      0.903          0.552          0.965               0               0  1.00E-03               10
# ..  ...        ...        ...            ...            ...        ...        ...            ...            ...             ...             ...       ...              ...
# 23  460    2.0E-04      0.919          0.613          0.973    2.4E-04      0.908          0.568          0.968               0               0  1.00E-04               10
# 24  480    1.9E-04      0.922          0.661          0.968    2.3E-04      0.909          0.610          0.961               0               0  1.00E-04               10
# 25  499    1.9E-04      0.923          0.684          0.965    2.3E-04      0.908          0.630          0.957               0               1  1.00E-04               10
#
# [26 rows x 13 columns]
# 100%|██████████| 500/500 [44:36<00:00,  5.35s/it]
# Run duration  2676.6917684078217
# Saving results to directory: ./cache/models/model_va_0.909_ps_21_tw_0_mc_true_dc_true_hm_false_npp_5_st_true_da_false
# Done
#
# Model trained on 9375 cell patches and 53365 non cell patches.
#
# Brief evaluation - Best validation accuracy model
# ----------------
# Epoch:	 480
# Training accuracy:	 0.922
# Validation accuracy:	 0.909
#
# Positive train accuracy:	 0.661
# Negative train accuracy:	 0.968
#
# Positive valid accuracy:	 0.610
# Negative valid accuracy:	 0.961
#
# 0.922 0.909 0.661 0.968 0.610 0.961
# 0.922 0.909 0.661 0.968 0.610 0.961
#
# Model trained on 9375 cell patches and 53365 non cell patches.
#
# Brief evaluation - Best training accuracy model
# ----------------
# Epoch:	 480
# Training accuracy:	 0.923
# Validation accuracy:	 0.908
#
# Positive train accuracy:	 0.684
# Negative train accuracy:	 0.965
#
# Positive valid accuracy:	 0.630
# Negative valid accuracy:	 0.957
#
# 0.923 0.908 0.684 0.965 0.630 0.957
# 0.923 0.908 0.684 0.965 0.630 0.957
# 0.9086707044947402

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024 / 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Creating (or loading from cache) data...
# --------------------------
# 100%|██████████| 8/8 [00:30<00:00,  3.84s/it]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/workspace/cell-tracking-ucl-thesis/train_model.py in train_model_demo(video_sessions, patch_size, temporal_width, mixed_channel_patches, drop_confocal_channel, do_hist_match, standardize_dataset, dataset_to_grayscale, apply_data_augmentation_to_dataset, valid_ratio, n_negatives_per_positive, train_params, try_load_data_from_cache, try_load_model_from_cache, additional_displays, device, v, vv)
#     174         if not try_load_model_from_cache:
# --> 175             raise FileNotFoundError
#     176
#
# FileNotFoundError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-86d7a1e703e1> in <module>
#      26                  train_params=deepcopy(train_params),
#      27                  try_load_data_from_cache=False,
# ---> 28                  try_load_model_from_cache=False,
#      29                 )
#      30 results.best_valid_accuracy
#
# ~/workspace/cell-tracking-ucl-thesis/train_model.py in train_model_demo(video_sessions, patch_size, temporal_width, mixed_channel_patches, drop_confocal_channel, do_hist_match, standardize_dataset, dataset_to_grayscale, apply_data_augmentation_to_dataset, valid_ratio, n_negatives_per_positive, train_params, try_load_data_from_cache, try_load_model_from_cache, additional_displays, device, v, vv)
#     233         model.train()
#     234         results: TrainingTracker = train(model, train_params, criterion=torch.nn.CrossEntropyLoss(),
# --> 235                                          additional_displays=additional_displays, device=device)
#     236
#     237         postfix = f'_ps_{patch_size[0]}_tw_{temporal_width}_mc_{str(mixed_channel_patches).lower()}'\
#
# ~/workspace/cell-tracking-ucl-thesis/cnnlearning.py in train(cnn, params, criterion, device, additional_displays)
#     691         params['trainset'],
#     692         batch_size=batch_size,
# --> 693         shuffle=True
#     694     )
#     695
#
# ~/deeplearning/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context)
#     217         if batch_size is not None and batch_sampler is None:
#     218             # auto_collation without custom batch_sampler
# --> 219             batch_sampler = BatchSampler(sampler, batch_size, drop_last)
#     220
#     221         self.batch_size = batch_size
#
# ~/deeplearning/lib/python3.6/site-packages/torch/utils/data/sampler.py in __init__(self, sampler, batch_size, drop_last)
#     188                 batch_size <= 0:
#     189             raise ValueError("batch_size should be a positive integer value, "
# --> 190                              "but got batch_size={}".format(batch_size))
#     191         if not isinstance(drop_last, bool):
#     192             raise ValueError("drop_last should be a boolean value, but got "
#
# ValueError: batch_size should be a positive integer value, but got batch_size=512.0

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024 / 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024 * 5, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024 * 5, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
train_params = collections.OrderedDict(
    epochs=500,
    lr = .001,
    
    weight_decay=0.001,
    batch_size=1024 * 6, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

model, results = train_model_demo(                
                 patch_size=21,
                 temporal_width=0,
    
                 mixed_channel_patches=True,
                 drop_confocal_channel=True,
    
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
    
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %% [markdown]
# ## Temporal width  3 - ps 31

# %%
train_params = collections.OrderedDict(
    epochs=250,
    lr = .001,
    
    weight_decay=0.01,
    batch_size=1024 * 2, # can be a number or None/'all' to train all trainset at once. 
    do_early_stop=True,  # Optional default True
    early_stop_patience=60, # How many epochs with no validation accuracy improvement before stopping early
    learning_rate_scheduler_patience=20, # How many epochs with no validation accuracy improvement before lowering learning rate
    evaluate_epochs=10,
    
    shuffle=True)

# %%
model, results = train_model_demo(
                 patch_size=41,
                 temporal_width=3,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=41,
                 temporal_width=3,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy

# %%
model, results = train_model_demo(
                 patch_size=45,
                 temporal_width=5,
                 do_hist_match=False,
                 n_negatives_per_positive=5,
                 standardize_dataset=True,
                
                 video_sessions = video_sessions_registered,
                 train_params=deepcopy(train_params),             
                 try_load_data_from_cache=False,
                 try_load_model_from_cache=False,
                )
results.best_valid_accuracy
